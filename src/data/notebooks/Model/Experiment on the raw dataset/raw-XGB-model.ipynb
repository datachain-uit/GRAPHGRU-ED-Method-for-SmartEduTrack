# %%
five_fold_files = {
    "week1": [
        "/kaggle/input/new-mooccubex/new-raw/clean_week1/train/5-folds/data_part_1.csv",
        "/kaggle/input/new-mooccubex/new-raw/clean_week1/train/5-folds/data_part_2.csv",
        "/kaggle/input/new-mooccubex/new-raw/clean_week1/train/5-folds/data_part_3.csv",
        "/kaggle/input/new-mooccubex/new-raw/clean_week1/train/5-folds/data_part_4.csv",
        "/kaggle/input/new-mooccubex/new-raw/clean_week1/train/5-folds/data_part_5.csv"
    ],
    "week2": [
        "/kaggle/input/new-mooccubex/new-raw/clean_week2/train/5-folds/data_part_1.csv",
        "/kaggle/input/new-mooccubex/new-raw/clean_week2/train/5-folds/data_part_2.csv",
        "/kaggle/input/new-mooccubex/new-raw/clean_week2/train/5-folds/data_part_3.csv",
        "/kaggle/input/new-mooccubex/new-raw/clean_week2/train/5-folds/data_part_4.csv",
        "/kaggle/input/new-mooccubex/new-raw/clean_week2/train/5-folds/data_part_5.csv"
    ],
    "week3": [
        "/kaggle/input/new-mooccubex/new-raw/clean_week3/train/5-folds/data_part_1.csv",
        "/kaggle/input/new-mooccubex/new-raw/clean_week3/train/5-folds/data_part_2.csv",
        "/kaggle/input/new-mooccubex/new-raw/clean_week3/train/5-folds/data_part_3.csv",
        "/kaggle/input/new-mooccubex/new-raw/clean_week3/train/5-folds/data_part_4.csv",
        "/kaggle/input/new-mooccubex/new-raw/clean_week3/train/5-folds/data_part_5.csv"
    ],
    "week4": [
        "/kaggle/input/new-mooccubex/new-raw/clean_week4/train/5-folds/data_part_1.csv",
        "/kaggle/input/new-mooccubex/new-raw/clean_week4/train/5-folds/data_part_2.csv",
        "/kaggle/input/new-mooccubex/new-raw/clean_week4/train/5-folds/data_part_3.csv",
        "/kaggle/input/new-mooccubex/new-raw/clean_week4/train/5-folds/data_part_4.csv",
        "/kaggle/input/new-mooccubex/new-raw/clean_week4/train/5-folds/data_part_5.csv"
    ]
}

file_validation = {
    "week1": [
        "/kaggle/input/new-mooccubex/new-raw/clean_week1/val/val_week1.csv"
    ],
    "week2": [
        "/kaggle/input/new-mooccubex/new-raw/clean_week2/val/val_week1_2.csv"
    ],
    "week3": [
        "/kaggle/input/new-mooccubex/new-raw/clean_week3/val/val_week1_2_3.csv"
    ],
    "week4": [
        "/kaggle/input/new-mooccubex/new-raw/clean_week4/val/val_week1_2_3_4.csv"
    ]
}

file_test = {
    "week1": [
        "/kaggle/input/new-mooccubex/new-raw/clean_week1/test/test_week1.csv"
    ],
    "week2": [
        "/kaggle/input/new-mooccubex/new-raw/clean_week2/test/test_week2.csv"
    ],
    "week3": [
        "/kaggle/input/new-mooccubex/new-raw/clean_week3/test/test_week3.csv"
    ],
    "week4": [
        "/kaggle/input/new-mooccubex/new-raw/clean_week4/test/test_week4.csv"
    ]
}

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
import time
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_recall_fscore_support
from xgboost import XGBClassifier
import xgboost as xgb
import numpy as np

# %% [markdown]
# ## Tìm siêu tham số tốt nhất cho từng tuần

# %%
# Tạo hàm train cho từng tuần
def train_week_model(week_number, file_paths_train, file_validation):
       # Đọc dữ liệu
    train_data = pd.read_csv(file_paths_train)
    val_data = pd.read_csv(file_validation)
    
    # Tách đặc trưng và nhãn
    X_train = train_data.drop(columns=["classification_encoded", "user_id", "course_id", "school", "enroll_time", "classification"])
    y_train = train_data["classification_encoded"]

    X_val = val_data.drop(columns=["classification_encoded", "user_id", "course_id", "school", "enroll_time", "classification"])
    y_val = val_data["classification_encoded"]
    
    # Áp dụng Over-sampling cho dữ liệu huấn luyện bằng SMOTE
    oversampler = SMOTE(sampling_strategy='auto', random_state=42)
    X_train_res, y_train_res = oversampler.fit_resample(X_train, y_train)
    
    model = XGBClassifier(random_state=42, use_label_encoder=False, eval_metric='logloss')
    # param_grid = {
    #     'n_estimators': [30],  # Giảm số cây hơn nữa
    #     'max_depth': [1],  # Độ sâu cây nhỏ hơn
    #     'learning_rate': [0.005],  # Tốc độ học rất chậm
    #     'gamma': [1],  # Regularization mạnh hơn
    #     'subsample': [0.5],  # Ngẫu nhiên hóa cao hơn
    #     'colsample_bytree': [0.5],  # Chọn ít đặc trưng hơn mỗi lần
    #     'min_child_weight': [10],  # Tăng ngưỡng mẫu trong mỗi lá
    #     'reg_alpha': [1],  # L1 regularization mạnh
    #     'reg_lambda': [2],  # L2 regularization mạnh
    #     'max_delta_step': [5]  # Giới hạn bước nhảy cao hơn
    # }
    param_grid = {
        'n_estimators': [30, 50],  # Giảm số cây hơn nữa
        'max_depth': [1, 2],  # Độ sâu cây nhỏ hơn
        'learning_rate': [0.005, 0.01],  # Tốc độ học rất chậm
        'gamma': [1, 2],  # Regularization mạnh hơn
        'subsample': [0.5],  # Ngẫu nhiên hóa cao hơn
        'colsample_bytree': [0.5],  # Chọn ít đặc trưng hơn mỗi lần
        'min_child_weight': [10, 20],  # Tăng ngưỡng mẫu trong mỗi lá
        'reg_alpha': [1, 2],  # L1 regularization mạnh
        'reg_lambda': [2, 3],  # L2 regularization mạnh
        'max_delta_step': [5, 10]  # Giới hạn bước nhảy cao hơn
    }
    # Khởi tạo RandomSearch tuner
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=10, scoring='accuracy',
                              verbose=2, n_jobs=-1)
        
    
   # Huấn luyện mô hình với các siêu tham số tốt nhất
    grid_search.fit(X_train_res, y_train_res)

    # Đánh giá mô hình
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(X_val)
    # Trả về kết quả tối ưu cho tuần
    best_params = grid_search.best_params_
    return best_params

# %%
# Định nghĩa đường dẫn đến dữ liệu cho từng tuần
file_paths_train = {
    "week1": "/kaggle/input/new-mooccubex/new-raw/clean_week1/train/clean_data_week1.csv",
    "week2": "/kaggle/input/new-mooccubex/new-raw/clean_week2/train/clean_data_week2.csv",
    "week3": "/kaggle/input/new-mooccubex/new-raw/clean_week3/train/clean_data_week3.csv",
    "week4": "/kaggle/input/new-mooccubex/new-raw/clean_week4/train/clean_data_week4.csv"
}

file_validation = {
    "week1": "/kaggle/input/new-mooccubex/new-raw/clean_week1/val/val_week1.csv",
    "week2": "/kaggle/input/new-mooccubex/new-raw/clean_week2/val/val_week1_2.csv",
    "week3": "/kaggle/input/new-mooccubex/new-raw/clean_week3/val/val_week1_2_3.csv",
    "week4": "/kaggle/input/new-mooccubex/new-raw/clean_week4/val/val_week1_2_3_4.csv"
}

# %%
# Tìm tham số tốt nhất cho từng tuần
best_params_week1 = train_week_model(1, file_paths_train["week1"], file_validation["week1"])
best_params_week2 = train_week_model(2, file_paths_train["week2"], file_validation["week2"])
best_params_week3 = train_week_model(3, file_paths_train["week3"], file_validation["week3"])
best_params_week4 = train_week_model(4, file_paths_train["week4"], file_validation["week4"])

# In thông tin chi tiết các tham số tối ưu
print("Best Parameters for Week 1:")
for param_name, param_value in best_params_week1.items():
       print(f"{param_name}: {param_value}")

print("\nBest Parameters for Week 2:")
for param_name, param_value in best_params_week2.items():
       print(f"{param_name}: {param_value}")

print("\nBest Parameters for Week 3:")
for param_name, param_value in best_params_week3.items():
       print(f"{param_name}: {param_value}")

print("\nBest Parameters for Week 4:")
for param_name, param_value in best_params_week4.items():
       print(f"{param_name}: {param_value}")
# Out:
# Fitting 10 folds for each of 256 candidates, totalling 2560 fits
# Fitting 10 folds for each of 256 candidates, totalling 2560 fits
# Fitting 10 folds for each of 256 candidates, totalling 2560 fits
# Fitting 10 folds for each of 256 candidates, totalling 2560 fits
# /usr/local/lib/python3.10/dist-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Best Parameters for Week 1:
# colsample_bytree: 0.5
# gamma: 1
# learning_rate: 0.005
# max_delta_step: 5
# max_depth: 2
# min_child_weight: 10
# n_estimators: 50
# reg_alpha: 2
# reg_lambda: 3
# subsample: 0.5
#
# Best Parameters for Week 2:
# colsample_bytree: 0.5
# gamma: 1
# learning_rate: 0.005
# max_delta_step: 5
# max_depth: 2
# min_child_weight: 20
# n_estimators: 50
# reg_alpha: 1
# reg_lambda: 3
# subsample: 0.5
#
# Best Parameters for Week 3:
# colsample_bytree: 0.5
# gamma: 1
# learning_rate: 0.005
# max_delta_step: 5
# max_depth: 2
# min_child_weight: 10
# n_estimators: 50
# reg_alpha: 1
# reg_lambda: 2
# subsample: 0.5
#
# Best Parameters for Week 4:
# colsample_bytree: 0.5
# gamma: 1
# learning_rate: 0.01
# max_delta_step: 5
# max_depth: 2
# min_child_weight: 20
# n_estimators: 50
# reg_alpha: 2
# reg_lambda: 3
# subsample: 0.5

# %%
# Danh sách tham số tốt nhất
best_params = {
    "week1": best_params_week1,
    "week2": best_params_week2,
    "week3": best_params_week3,
    "week4": best_params_week4
}

# %% [markdown]
# ## XGBoost với các tham sốt nhất cho mỗi tuần

# %%
# Biến lưu kết quả tổng quát
overall_results_5folds = []

# Lặp qua từng tuần
for week, file_paths in five_fold_files.items():
    print(f"\nProcessing {week} with best parameters...")
    params = best_params[week]
    print(f"best parameters for {week}: {params}")
    
    # Biến lưu kết quả cho từng tuần
    week_results = {
        "week": week,
        "accuracy_per_fold": [],
        "precision_per_label": [],
        "recall_per_label": [],
        "f1_score_per_label": [],
        "confusion_matrices": [],
        "train_times": [],
        "test_times": []
    }

    # Lặp qua từng fold
    for i in range(len(file_paths)):
        print(f"Fold {i+1}: Using file {file_paths[i]} as test set")
        
        # Tải dữ liệu
        test_data = pd.read_csv(file_paths[i])
        train_data = pd.concat([pd.read_csv(file_paths[j]) for j in range(len(file_paths)) if j != i])
        
        # Tách X và y
        X_train = train_data.drop(columns=["classification_encoded", "user_id",
                                           "course_id", "school", "enroll_time", "classification"])
        y_train = train_data['classification_encoded']
        
        X_test = test_data.drop(columns=["classification_encoded", "user_id",
                                         "course_id", "school", "enroll_time", "classification"])
        y_test = test_data['classification_encoded']


        # Xây dựng mô hình với tham số tốt nhất
        model = xgb.XGBClassifier(**params)
        
        # Bắt đầu tính thời gian huấn luyện
        start_train = time.time()
        model.fit(X_train, y_train)
        end_train = time.time()
        
        # Bắt đầu tính thời gian kiểm thử
        start_test = time.time()
        y_pred = model.predict(X_test)
        end_test = time.time()
        
        # Tính thời gian và lưu lại
        train_time = end_train - start_train
        test_time = end_test - start_test
        week_results["train_times"].append(train_time)
        week_results["test_times"].append(test_time)

        # Đánh giá mô hình trên tập kiểm thử của fold hiện tại
        accuracy = accuracy_score(y_test, y_pred)
        week_results["accuracy_per_fold"].append(accuracy)
        # Dự đoán

        
        # Tính các chỉ số cho mỗi fold
        precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average=None)
        conf_matrix = confusion_matrix(y_test, y_pred)
        
        week_results["precision_per_label"].append(precision)
        week_results["recall_per_label"].append(recall)
        week_results["f1_score_per_label"].append(f1)
        week_results["confusion_matrices"].append(conf_matrix)

    # Tính trung bình cho từng nhãn
    average_precision_per_label = np.mean(week_results["precision_per_label"], axis=0)
    average_recall_per_label = np.mean(week_results["recall_per_label"], axis=0)
    average_f1_per_label = np.mean(week_results["f1_score_per_label"], axis=0)
    average_confusion_matrix = np.mean(week_results["confusion_matrices"], axis=0)
    average_train_time = sum(week_results["train_times"]) / len(week_results["train_times"])
    average_test_time = sum(week_results["test_times"]) / len(week_results["test_times"])
    
    # Tạo DataFrame cho precision, recall, f1-score
    labels = np.unique(y_test)  # Lấy nhãn từ y_test_classes
    metrics_df = pd.DataFrame({
        "Label": labels,
        "Average Precision": average_precision_per_label,
        "Average Recall": average_recall_per_label,
        "Average F1-Score": average_f1_per_label
    })
    
    # Tạo DataFrame cho confusion matrix|
    confusion_df = pd.DataFrame(average_confusion_matrix, index=labels, columns=labels)
    
    # In kết quả
    print("\n=== Average Precision, Recall, F1-Score per Label ===")
    print(metrics_df)
    print("\n=== Average Confusion Matrix ===")
    print(confusion_df)

    # Lưu kết quả tuần vào kết quả tổng quát
    week_results["average_train_times"] = average_train_time
    week_results["average_test_times"] = average_test_time
    week_results["average_metrics_df"] = metrics_df
    week_results["average_confusion_matrix"] = confusion_df
    overall_results_5folds.append(week_results)
# Out:
# Processing week1 with best parameters...
# best parameters for week1: {'colsample_bytree': 0.5, 'gamma': 1, 'learning_rate': 0.005, 'max_delta_step': 5, 'max_depth': 2, 'min_child_weight': 10, 'n_estimators': 50, 'reg_alpha': 2, 'reg_lambda': 3, 'subsample': 0.5}
# Fold 1: Using file /kaggle/input/new-mooccubex/new-raw/clean_week1/train/5-folds/data_part_1.csv as test set
# Fold 2: Using file /kaggle/input/new-mooccubex/new-raw/clean_week1/train/5-folds/data_part_2.csv as test set
# Fold 3: Using file /kaggle/input/new-mooccubex/new-raw/clean_week1/train/5-folds/data_part_3.csv as test set
# Fold 4: Using file /kaggle/input/new-mooccubex/new-raw/clean_week1/train/5-folds/data_part_4.csv as test set
# Fold 5: Using file /kaggle/input/new-mooccubex/new-raw/clean_week1/train/5-folds/data_part_5.csv as test set
#
# === Average Precision, Recall, F1-Score per Label ===
#    Label  Average Precision  Average Recall  Average F1-Score
# 0      0           0.786164        0.357333          0.490557
# 1      1           1.000000        0.056949          0.106607
# 2      2           0.881780        0.396563          0.537885
# 3      3           0.883471        0.195210          0.318993
# 4      4           0.706672        0.984034          0.822540
#
# === Average Confusion Matrix ===
#        0    1     2     3       4
# 0  214.4  0.0   5.6   0.4   379.6
# 1   10.2  5.0   0.0   0.2    72.2
# 2   16.8  0.0  65.2   0.4    82.0
# 3   12.0  0.0   0.6  32.6   121.8
# 4   19.6  0.0   3.0   3.0  1577.8
#
# Processing week2 with best parameters...
# best parameters for week2: {'colsample_bytree': 0.5, 'gamma': 1, 'learning_rate': 0.005, 'max_delta_step': 5, 'max_depth': 2, 'min_child_weight': 20, 'n_estimators': 50, 'reg_alpha': 1, 'reg_lambda': 3, 'subsample': 0.5}
# Fold 1: Using file /kaggle/input/new-mooccubex/new-raw/clean_week2/train/5-folds/data_part_1.csv as test set
# Fold 2: Using file /kaggle/input/new-mooccubex/new-raw/clean_week2/train/5-folds/data_part_2.csv as test set
# Fold 3: Using file /kaggle/input/new-mooccubex/new-raw/clean_week2/train/5-folds/data_part_3.csv as test set
# Fold 4: Using file /kaggle/input/new-mooccubex/new-raw/clean_week2/train/5-folds/data_part_4.csv as test set
# Fold 5: Using file /kaggle/input/new-mooccubex/new-raw/clean_week2/train/5-folds/data_part_5.csv as test set
#
# === Average Precision, Recall, F1-Score per Label ===
#    Label  Average Precision  Average Recall  Average F1-Score
# 0      0           0.798805        0.362333          0.498001
# 1      1           1.000000        0.061494          0.114247
# 2      2           0.886897        0.328463          0.474467
# 3      3           0.907492        0.144910          0.249059
# 4      4           0.701636        0.987402          0.820314
#
# === Average Confusion Matrix ===
#        0    1     2     3       4
# 0  217.4  0.0   5.0   0.2   377.4
# 1    9.2  5.4   0.0   0.4    72.6
# 2   15.6  0.0  54.0   0.6    94.2
# 3   12.8  0.0   0.6  24.2   129.4
# 4   17.4  0.0   1.8   1.0  1583.2
#
# Processing week3 with best parameters...
# best parameters for week3: {'colsample_bytree': 0.5, 'gamma': 1, 'learning_rate': 0.005, 'max_delta_step': 5, 'max_depth': 2, 'min_child_weight': 10, 'n_estimators': 50, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 0.5}
# Fold 1: Using file /kaggle/input/new-mooccubex/new-raw/clean_week3/train/5-folds/data_part_1.csv as test set
# Fold 2: Using file /kaggle/input/new-mooccubex/new-raw/clean_week3/train/5-folds/data_part_2.csv as test set
# Fold 3: Using file /kaggle/input/new-mooccubex/new-raw/clean_week3/train/5-folds/data_part_3.csv as test set
# Fold 4: Using file /kaggle/input/new-mooccubex/new-raw/clean_week3/train/5-folds/data_part_4.csv as test set
# Fold 5: Using file /kaggle/input/new-mooccubex/new-raw/clean_week3/train/5-folds/data_part_5.csv as test set
#
# === Average Precision, Recall, F1-Score per Label ===
#    Label  Average Precision  Average Recall  Average F1-Score
# 0      0           0.807534        0.284000          0.419856
# 1      1           1.000000        0.070611          0.130195
# 2      2           0.874541        0.335765          0.480687
# 3      3           0.925864        0.173653          0.292134
# 4      4           0.687809        0.991145          0.812067
#
# === Average Confusion Matrix ===
#        0    1     2     3       4
# 0  170.4  0.0   5.4   0.0   424.2
# 1    6.8  6.2   0.0   0.0    74.6
# 2   12.4  0.0  55.2   0.8    96.0
# 3   10.8  0.0   0.6  29.0   126.6
# 4   10.4  0.0   2.4   1.4  1589.2
#
# Processing week4 with best parameters...
# best parameters for week4: {'colsample_bytree': 0.5, 'gamma': 1, 'learning_rate': 0.01, 'max_delta_step': 5, 'max_depth': 2, 'min_child_weight': 20, 'n_estimators': 50, 'reg_alpha': 2, 'reg_lambda': 3, 'subsample': 0.5}
# Fold 1: Using file /kaggle/input/new-mooccubex/new-raw/clean_week4/train/5-folds/data_part_1.csv as test set
# Fold 2: Using file /kaggle/input/new-mooccubex/new-raw/clean_week4/train/5-folds/data_part_2.csv as test set
# Fold 3: Using file /kaggle/input/new-mooccubex/new-raw/clean_week4/train/5-folds/data_part_3.csv as test set
# Fold 4: Using file /kaggle/input/new-mooccubex/new-raw/clean_week4/train/5-folds/data_part_4.csv as test set
# Fold 5: Using file /kaggle/input/new-mooccubex/new-raw/clean_week4/train/5-folds/data_part_5.csv as test set
#
# === Average Precision, Recall, F1-Score per Label ===
#    Label  Average Precision  Average Recall  Average F1-Score
# 0      0           0.844056        0.272333          0.411631
# 1      1           0.575123        0.141327          0.225361
# 2      2           0.890087        0.479342          0.619049
# 3      3           0.992593        0.128144          0.224999
# 4      4           0.693418        0.993264          0.816684
#
# === Average Confusion Matrix ===
#        0     1     2     3       4
# 0  163.4   6.8   5.6   0.0   424.2
# 1    3.4  12.4   0.0   0.2    71.6
# 2    9.0   1.4  78.8   0.0    75.2
# 3   10.8   1.0   0.6  21.4   133.2
# 4    7.0   0.0   3.8   0.0  1592.6

# %% [markdown]
# ## Kết quả 5-folds

# %%
# Duyệt qua các tuần trong overall_results
for week_result in overall_results_5folds:
    week = week_result["week"]
    average_train_time = np.mean(week_result["train_times"])
    average_test_time = np.mean(week_result["test_times"])
    average_metrics_df = week_result["average_metrics_df"]
    average_confusion_matrix = week_result["average_confusion_matrix"]
    
    # In kết quả
    print(f"\n=== Results for {week} ===")
    print(f"Average Train Time: {average_train_time:.4f} seconds")
    print(f"Average Test Time: {average_test_time:.4f} seconds")
    print("\nAverage Precision, Recall, F1-Score per Label:")
    print(average_metrics_df)
    print("\nAverage Confusion Matrix:")
    print(average_confusion_matrix)
# Out:
# === Results for week1 ===
# Average Train Time: 0.1614 seconds
# Average Test Time: 0.0061 seconds
#
# Average Precision, Recall, F1-Score per Label:
#    Label  Average Precision  Average Recall  Average F1-Score
# 0      0           0.786164        0.357333          0.490557
# 1      1           1.000000        0.056949          0.106607
# 2      2           0.881780        0.396563          0.537885
# 3      3           0.883471        0.195210          0.318993
# 4      4           0.706672        0.984034          0.822540
#
# Average Confusion Matrix:
#        0    1     2     3       4
# 0  214.4  0.0   5.6   0.4   379.6
# 1   10.2  5.0   0.0   0.2    72.2
# 2   16.8  0.0  65.2   0.4    82.0
# 3   12.0  0.0   0.6  32.6   121.8
# 4   19.6  0.0   3.0   3.0  1577.8
#
# === Results for week2 ===
# Average Train Time: 0.2023 seconds
# Average Test Time: 0.0085 seconds
#
# Average Precision, Recall, F1-Score per Label:
#    Label  Average Precision  Average Recall  Average F1-Score
# 0      0           0.798805        0.362333          0.498001
# 1      1           1.000000        0.061494          0.114247
# 2      2           0.886897        0.328463          0.474467
# 3      3           0.907492        0.144910          0.249059
# 4      4           0.701636        0.987402          0.820314
#
# Average Confusion Matrix:
#        0    1     2     3       4
# 0  217.4  0.0   5.0   0.2   377.4
# 1    9.2  5.4   0.0   0.4    72.6
# 2   15.6  0.0  54.0   0.6    94.2
# 3   12.8  0.0   0.6  24.2   129.4
# 4   17.4  0.0   1.8   1.0  1583.2
#
# === Results for week3 ===
# Average Train Time: 0.2007 seconds
# Average Test Time: 0.0076 seconds
#
# Average Precision, Recall, F1-Score per Label:
#    Label  Average Precision  Average Recall  Average F1-Score
# 0      0           0.807534        0.284000          0.419856
# 1      1           1.000000        0.070611          0.130195
# 2      2           0.874541        0.335765          0.480687
# 3      3           0.925864        0.173653          0.292134
# 4      4           0.687809        0.991145          0.812067
#
# Average Confusion Matrix:
#        0    1     2     3       4
# 0  170.4  0.0   5.4   0.0   424.2
# 1    6.8  6.2   0.0   0.0    74.6
# 2   12.4  0.0  55.2   0.8    96.0
# 3   10.8  0.0   0.6  29.0   126.6
# 4   10.4  0.0   2.4   1.4  1589.2
#
# === Results for week4 ===
# Average Train Time: 0.2393 seconds
# Average Test Time: 0.0087 seconds
#
# Average Precision, Recall, F1-Score per Label:
#    Label  Average Precision  Average Recall  Average F1-Score
# 0      0           0.844056        0.272333          0.411631
# 1      1           0.575123        0.141327          0.225361
# 2      2           0.890087        0.479342          0.619049
# 3      3           0.992593        0.128144          0.224999
# 4      4           0.693418        0.993264          0.816684
#
# Average Confusion Matrix:
#        0     1     2     3       4
# 0  163.4   6.8   5.6   0.0   424.2
# 1    3.4  12.4   0.0   0.2    71.6
# 2    9.0   1.4  78.8   0.0    75.2
# 3   10.8   1.0   0.6  21.4   133.2
# 4    7.0   0.0   3.8   0.0  1592.6

# %% [markdown]
# ## Test trên tập test

# %%
# Mảng lưu dữ liệu của các tuần
results = []

def process_week(week_num, best_params, results):
    print(f"\n=== Processing Week {week_num} ===")
    params = best_params[week]
    # Đường dẫn tới dữ liệu tuần tương ứng
    train_path = f"/kaggle/input/new-mooccubex/new-raw/clean_week{week_num}/train/clean_data_week{week_num}.csv"
    test_path = f"/kaggle/input/new-mooccubex/new-raw/clean_week{week_num}/test/test_week{week_num}.csv"
    
    # Load dữ liệu
    train_data = pd.read_csv(train_path)
    test_data = pd.read_csv(test_path)
    
    # Tách X và y
    X_train = train_data.drop(columns=["classification_encoded", "user_id",
                                       "course_id", "school", "enroll_time", "classification"])
    y_train = train_data['classification_encoded']
    
    X_test = test_data.drop(columns=["classification_encoded", "user_id",
                                     "course_id", "school", "enroll_time", "classification"])
    y_test = test_data['classification_encoded']

    # Áp dụng SMOTE cho tập huấn luyện
    smote = SMOTE(random_state=42)
    X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

    # Xây dựng mô hình với tham số tốt nhất
    model = xgb.XGBClassifier(**params)
    
    # Huấn luyện mô hình
    start_train = time.time()
    model.fit(X_train, y_train)
    end_train = time.time()
    
    # Kiểm thử mô hình
    start_test = time.time()
    y_pred = model.predict(X_test)
    end_test = time.time()
    
    # Tính thời gian huấn luyện và kiểm thử
    train_time = end_train - start_train
    test_time = end_test - start_test
    
    
    precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average=None)
    conf_matrix = confusion_matrix(y_test, y_pred)
    
    # Lưu kết quả vào mảng
    results.append({
        "week": week_num,
        "train_time": train_time,
        "test_time": test_time,
        "precision": precision,
        "recall": recall,
        "f1_score": f1,
        "confusion_matrix": conf_matrix
    })
    
    print("\n=== Precision, Recall, F1-Score per Label ===")
    print(pd.DataFrame({
        "Label": np.unique(y_test),
        "Precision": precision,
        "Recall": recall,
        "F1-Score": f1
    }))
    print("\n=== Confusion Matrix ===")
    print(pd.DataFrame(conf_matrix, index=np.unique(y_test), columns=np.unique(y_test)))
    
    print(f"\nTrain Time: {train_time:.2f} seconds")
    print(f"Test Time: {test_time:.2f} seconds")

# %%
process_week(1, best_params, results)
# Out:
# === Processing Week 1 ===
#
# === Precision, Recall, F1-Score per Label ===
#    Label  Precision    Recall  F1-Score
# 0      0   0.790795  0.504000  0.615635
# 1      1   1.000000  0.018519  0.036364
# 2      2   0.933333  0.407767  0.567568
# 3      3   0.846154  0.209524  0.335878
# 4      4   0.735892  0.975075  0.838765
#
# === Confusion Matrix ===
#      0  1   2   3    4
# 0  189  0   2   0  184
# 1    8  1   0   0   45
# 2   17  0  42   0   44
# 3    4  0   1  22   78
# 4   21  0   0   4  978
#
# Train Time: 0.18 seconds
# Test Time: 0.00 seconds

# %%
process_week(2, best_params, results)
# Out:
# === Processing Week 2 ===
#
# === Precision, Recall, F1-Score per Label ===
#    Label  Precision    Recall  F1-Score
# 0      0   0.872832  0.402667  0.551095
# 1      1   1.000000  0.037037  0.071429
# 2      2   0.921053  0.339806  0.496454
# 3      3   1.000000  0.114286  0.205128
# 4      4   0.703180  0.992024  0.822994
#
# === Confusion Matrix ===
#      0  1   2   3    4
# 0  151  0   2   0  222
# 1    3  2   0   0   49
# 2    8  0  35   0   60
# 3    3  0   1  12   89
# 4    8  0   0   0  995
#
# Train Time: 0.20 seconds
# Test Time: 0.01 seconds

# %%
process_week(3, best_params, results)
# Out:
# === Processing Week 3 ===
#
# === Precision, Recall, F1-Score per Label ===
#    Label  Precision    Recall  F1-Score
# 0      0   0.841176  0.381333  0.524771
# 1      1   1.000000  0.037037  0.071429
# 2      2   0.925000  0.359223  0.517483
# 3      3   0.882353  0.142857  0.245902
# 4      4   0.705174  0.992024  0.824358
#
# === Confusion Matrix ===
#      0  1   2   3    4
# 0  143  0   2   0  230
# 1    8  2   0   0   44
# 2   10  0  37   0   56
# 3    3  0   1  15   86
# 4    6  0   0   2  995
#
# Train Time: 0.23 seconds
# Test Time: 0.01 seconds

# %%
process_week(4, best_params, results)
# Out:
# === Processing Week 4 ===
#
# === Precision, Recall, F1-Score per Label ===
#    Label  Precision    Recall  F1-Score
# 0      0   0.807143  0.301333  0.438835
# 1      1   0.666667  0.111111  0.190476
# 2      2   0.942308  0.475728  0.632258
# 3      3   1.000000  0.114286  0.205128
# 4      4   0.696566  0.991027  0.818107
#
# === Confusion Matrix ===
#      0  1   2   3    4
# 0  113  1   2   0  259
# 1    8  6   0   0   40
# 2    8  1  49   0   45
# 3    2  1   1  12   89
# 4    9  0   0   0  994
#
# Train Time: 0.25 seconds
# Test Time: 0.01 seconds

# %%
# Hiển thị dữ liệu của các tuần
print("\n=== Summary Results for All Weeks ===")
for result in results:
    print(f"Week {result['week']}:")
    print(f"  Train Time: {result['train_time']:.2f} seconds")
    print(f"  Test Time: {result['test_time']:.2f} seconds")
    print(f"  Precision: {result['precision']}")
    print(f"  Recall: {result['recall']}")
    print(f"  F1-Score: {result['f1_score']}")
    print(f"  Confusion Matrix:\n{result['confusion_matrix']}")
# Out:
# === Summary Results for All Weeks ===
# Week 1:
#   Train Time: 0.18 seconds
#   Test Time: 0.00 seconds
#   Precision: [0.79079498 1.         0.93333333 0.84615385 0.73589165]
#   Recall: [0.504      0.01851852 0.40776699 0.20952381 0.97507478]
#   F1-Score: [0.61563518 0.03636364 0.56756757 0.33587786 0.83876501]
#   Confusion Matrix:
# [[189   0   2   0 184]
#  [  8   1   0   0  45]
#  [ 17   0  42   0  44]
#  [  4   0   1  22  78]
#  [ 21   0   0   4 978]]
# Week 2:
#   Train Time: 0.20 seconds
#   Test Time: 0.01 seconds
#   Precision: [0.87283237 1.         0.92105263 1.         0.70318021]
#   Recall: [0.40266667 0.03703704 0.33980583 0.11428571 0.99202393]
#   F1-Score: [0.55109489 0.07142857 0.4964539  0.20512821 0.82299421]
#   Confusion Matrix:
# [[151   0   2   0 222]
#  [  3   2   0   0  49]
#  [  8   0  35   0  60]
#  [  3   0   1  12  89]
#  [  8   0   0   0 995]]
# Week 3:
#   Train Time: 0.23 seconds
#   Test Time: 0.01 seconds
#   Precision: [0.84117647 1.         0.925      0.88235294 0.70517364]
#   Recall: [0.38133333 0.03703704 0.3592233  0.14285714 0.99202393]
#   F1-Score: [0.52477064 0.07142857 0.51748252 0.24590164 0.82435791]
#   Confusion Matrix:
# [[143   0   2   0 230]
#  [  8   2   0   0  44]
#  [ 10   0  37   0  56]
#  [  3   0   1  15  86]
#  [  6   0   0   2 995]]
# Week 4:
#   Train Time: 0.25 seconds
#   Test Time: 0.01 seconds
#   Precision: [0.80714286 0.66666667 0.94230769 1.         0.69656622]
#   Recall: [0.30133333 0.11111111 0.47572816 0.11428571 0.99102692]
#   F1-Score: [0.43883495 0.19047619 0.63225806 0.20512821 0.818107  ]
#   Confusion Matrix:
# [[113   1   2   0 259]
#  [  8   6   0   0  40]
#  [  8   1  49   0  45]
#  [  2   1   1  12  89]
#  [  9   0   0   0 994]]
