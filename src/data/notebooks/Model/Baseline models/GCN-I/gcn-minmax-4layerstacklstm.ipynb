# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/clean_raw_data.csv
# /kaggle/input/clean_data_mean.csv
# /kaggle/input/raw_data.csv
# /kaggle/input/clean_data_GCN.csv
# /kaggle/input/FillZero_minmax_baseline/clean_data_minmax_fill-zero.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week2/val/val_week1_2.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week2/test/test_week2.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week2/train/clean_data_week2.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week2/train/5-folds/data_part_2.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week2/train/5-folds/data_part_3.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week2/train/5-folds/data_part_4.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week2/train/5-folds/data_part_1.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week2/train/5-folds/data_part_5.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week3/val/val_week1_2_3.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week3/test/test_week3.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week3/train/clean_data_week3.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week3/train/5-folds/data_part_2.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week3/train/5-folds/data_part_3.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week3/train/5-folds/data_part_4.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week3/train/5-folds/data_part_1.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week3/train/5-folds/data_part_5.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week1/val/val_week1.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week1/test/test_week1.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week1/train/clean_data_week1.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week1/train/5-folds/data_part_2.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week1/train/5-folds/data_part_3.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week1/train/5-folds/data_part_4.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week1/train/5-folds/data_part_1.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week1/train/5-folds/data_part_5.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week4/val/val_week1_2_3_4.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week4/test/test_week4.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week4/train/clean_data_week4.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week4/train/5-folds/data_part_2.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week4/train/5-folds/data_part_3.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week4/train/5-folds/data_part_4.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week4/train/5-folds/data_part_1.csv
# /kaggle/input/FillZero_minmax_baseline/clean_week4/train/5-folds/data_part_5.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_data_minmax_GCN_version4.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week2/val/val_week1_2.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week2/test/test_week2.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week2/train/clean_data_week2.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week2/train/5-folds/data_part_2.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week2/train/5-folds/data_part_3.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week2/train/5-folds/data_part_4.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week2/train/5-folds/data_part_1.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week2/train/5-folds/data_part_5.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week3/val/val_week1_2_3.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week3/test/test_week3.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week3/train/clean_data_week3.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week3/train/5-folds/data_part_2.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week3/train/5-folds/data_part_3.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week3/train/5-folds/data_part_4.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week3/train/5-folds/data_part_1.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week3/train/5-folds/data_part_5.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week1/val/val_week1.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week1/test/test_week1.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week1/train/clean_data_week1.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week1/train/5-folds/data_part_2.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week1/train/5-folds/data_part_3.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week1/train/5-folds/data_part_4.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week1/train/5-folds/data_part_1.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week1/train/5-folds/data_part_5.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week4/val/val_week1_2_3_4.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week4/test/test_week4.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week4/train/clean_data_week4.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week4/train/5-folds/data_part_2.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week4/train/5-folds/data_part_3.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week4/train/5-folds/data_part_4.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week4/train/5-folds/data_part_1.csv
# /kaggle/input/GCN_minmax_baseline_version4/clean_week4/train/5-folds/data_part_5.csv
# /kaggle/input/Fill-1_baseline/clean_data_Fill-1.csv
# /kaggle/input/Fill-1_baseline/clean_week2/val/val_week1_2.csv
# /kaggle/input/Fill-1_baseline/clean_week2/test/test_week2.csv
# /kaggle/input/Fill-1_baseline/clean_week2/train/clean_data_week2.csv
# /kaggle/input/Fill-1_baseline/clean_week2/train/5-folds/data_part_2.csv
# /kaggle/input/Fill-1_baseline/clean_week2/train/5-folds/data_part_3.csv
# /kaggle/input/Fill-1_baseline/clean_week2/train/5-folds/data_part_4.csv
# /kaggle/input/Fill-1_baseline/clean_week2/train/5-folds/data_part_1.csv
# /kaggle/input/Fill-1_baseline/clean_week2/train/5-folds/data_part_5.csv
# /kaggle/input/Fill-1_baseline/clean_week3/val/val_week1_2_3.csv
# /kaggle/input/Fill-1_baseline/clean_week3/test/test_week3.csv
# /kaggle/input/Fill-1_baseline/clean_week3/train/clean_data_week3.csv
# /kaggle/input/Fill-1_baseline/clean_week3/train/5-folds/data_part_2.csv
# /kaggle/input/Fill-1_baseline/clean_week3/train/5-folds/data_part_3.csv
# /kaggle/input/Fill-1_baseline/clean_week3/train/5-folds/data_part_4.csv
# /kaggle/input/Fill-1_baseline/clean_week3/train/5-folds/data_part_1.csv
# /kaggle/input/Fill-1_baseline/clean_week3/train/5-folds/data_part_5.csv
# /kaggle/input/Fill-1_baseline/clean_week1/val/val_week1.csv
# /kaggle/input/Fill-1_baseline/clean_week1/test/test_week1.csv
# /kaggle/input/Fill-1_baseline/clean_week1/train/clean_data_week1.csv
# /kaggle/input/Fill-1_baseline/clean_week1/train/5-folds/data_part_2.csv
# /kaggle/input/Fill-1_baseline/clean_week1/train/5-folds/data_part_3.csv
# /kaggle/input/Fill-1_baseline/clean_week1/train/5-folds/data_part_4.csv
# /kaggle/input/Fill-1_baseline/clean_week1/train/5-folds/data_part_1.csv
# /kaggle/input/Fill-1_baseline/clean_week1/train/5-folds/data_part_5.csv
# /kaggle/input/Fill-1_baseline/clean_week4/val/val_week1_2_3_4.csv
# /kaggle/input/Fill-1_baseline/clean_week4/test/test_week4.csv
# /kaggle/input/Fill-1_baseline/clean_week4/train/clean_data_week4.csv
# /kaggle/input/Fill-1_baseline/clean_week4/train/5-folds/data_part_2.csv
# /kaggle/input/Fill-1_baseline/clean_week4/train/5-folds/data_part_3.csv
# /kaggle/input/Fill-1_baseline/clean_week4/train/5-folds/data_part_4.csv
# /kaggle/input/Fill-1_baseline/clean_week4/train/5-folds/data_part_1.csv
# /kaggle/input/Fill-1_baseline/clean_week4/train/5-folds/data_part_5.csv
# /kaggle/input/GCN_minmax_baseline/clean_data_minmax_GCN.csv
# /kaggle/input/GCN_minmax_baseline/clean_week2/val/val_week1_2.csv
# /kaggle/input/GCN_minmax_baseline/clean_week2/test/test_week2.csv
# /kaggle/input/GCN_minmax_baseline/clean_week2/train/clean_data_week2.csv
# /kaggle/input/GCN_minmax_baseline/clean_week2/train/5-folds/data_part_2.csv
# /kaggle/input/GCN_minmax_baseline/clean_week2/train/5-folds/data_part_3.csv
# /kaggle/input/GCN_minmax_baseline/clean_week2/train/5-folds/data_part_4.csv
# /kaggle/input/GCN_minmax_baseline/clean_week2/train/5-folds/data_part_1.csv
# /kaggle/input/GCN_minmax_baseline/clean_week2/train/5-folds/data_part_5.csv
# /kaggle/input/GCN_minmax_baseline/clean_week3/val/val_week1_2_3.csv
# /kaggle/input/GCN_minmax_baseline/clean_week3/test/test_week3.csv
# /kaggle/input/GCN_minmax_baseline/clean_week3/train/clean_data_week3.csv
# /kaggle/input/GCN_minmax_baseline/clean_week3/train/5-folds/data_part_2.csv
# /kaggle/input/GCN_minmax_baseline/clean_week3/train/5-folds/data_part_3.csv
# /kaggle/input/GCN_minmax_baseline/clean_week3/train/5-folds/data_part_4.csv
# /kaggle/input/GCN_minmax_baseline/clean_week3/train/5-folds/data_part_1.csv
# /kaggle/input/GCN_minmax_baseline/clean_week3/train/5-folds/data_part_5.csv
# /kaggle/input/GCN_minmax_baseline/clean_week1/val/val_week1.csv
# /kaggle/input/GCN_minmax_baseline/clean_week1/test/test_week1.csv
# /kaggle/input/GCN_minmax_baseline/clean_week1/train/clean_data_week1.csv
# /kaggle/input/GCN_minmax_baseline/clean_week1/train/5-folds/data_part_2.csv
# /kaggle/input/GCN_minmax_baseline/clean_week1/train/5-folds/data_part_3.csv
# /kaggle/input/GCN_minmax_baseline/clean_week1/train/5-folds/data_part_4.csv
# /kaggle/input/GCN_minmax_baseline/clean_week1/train/5-folds/data_part_1.csv
# /kaggle/input/GCN_minmax_baseline/clean_week1/train/5-folds/data_part_5.csv
# /kaggle/input/GCN_minmax_baseline/clean_week4/val/val_week1_2_3_4.csv
# /kaggle/input/GCN_minmax_baseline/clean_week4/test/test_week4.csv
# /kaggle/input/GCN_minmax_baseline/clean_week4/train/clean_data_week4.csv
# /kaggle/input/GCN_minmax_baseline/clean_week4/train/5-folds/data_part_2.csv
# /kaggle/input/GCN_minmax_baseline/clean_week4/train/5-folds/data_part_3.csv
# /kaggle/input/GCN_minmax_baseline/clean_week4/train/5-folds/data_part_4.csv
# /kaggle/input/GCN_minmax_baseline/clean_week4/train/5-folds/data_part_1.csv
# /kaggle/input/GCN_minmax_baseline/clean_week4/train/5-folds/data_part_5.csv
# /kaggle/input/Mean_minmax_baseline/clean_week2/val/val_week1_2.csv
# /kaggle/input/Mean_minmax_baseline/clean_week2/test/test_week2.csv
# /kaggle/input/Mean_minmax_baseline/clean_week2/train/clean_data_week2.csv
# /kaggle/input/Mean_minmax_baseline/clean_week2/train/5-folds/data_part_2.csv
# /kaggle/input/Mean_minmax_baseline/clean_week2/train/5-folds/data_part_3.csv
# /kaggle/input/Mean_minmax_baseline/clean_week2/train/5-folds/data_part_4.csv
# /kaggle/input/Mean_minmax_baseline/clean_week2/train/5-folds/data_part_1.csv
# /kaggle/input/Mean_minmax_baseline/clean_week2/train/5-folds/data_part_5.csv
# /kaggle/input/Mean_minmax_baseline/clean_week3/val/val_week1_2_3.csv
# /kaggle/input/Mean_minmax_baseline/clean_week3/test/test_week3.csv
# /kaggle/input/Mean_minmax_baseline/clean_week3/train/clean_data_week3.csv
# /kaggle/input/Mean_minmax_baseline/clean_week3/train/5-folds/data_part_2.csv
# /kaggle/input/Mean_minmax_baseline/clean_week3/train/5-folds/data_part_3.csv
# /kaggle/input/Mean_minmax_baseline/clean_week3/train/5-folds/data_part_4.csv
# /kaggle/input/Mean_minmax_baseline/clean_week3/train/5-folds/data_part_1.csv
# /kaggle/input/Mean_minmax_baseline/clean_week3/train/5-folds/data_part_5.csv
# /kaggle/input/Mean_minmax_baseline/clean_week1/val/val_week1.csv
# /kaggle/input/Mean_minmax_baseline/clean_week1/test/test_week1.csv
# /kaggle/input/Mean_minmax_baseline/clean_week1/train/clean_data_week1.csv
# /kaggle/input/Mean_minmax_baseline/clean_week1/train/5-folds/data_part_2.csv
# /kaggle/input/Mean_minmax_baseline/clean_week1/train/5-folds/data_part_3.csv
# /kaggle/input/Mean_minmax_baseline/clean_week1/train/5-folds/data_part_4.csv
# /kaggle/input/Mean_minmax_baseline/clean_week1/train/5-folds/data_part_1.csv
# /kaggle/input/Mean_minmax_baseline/clean_week1/train/5-folds/data_part_5.csv
# /kaggle/input/Mean_minmax_baseline/clean_week4/val/val_week1_2_3_4.csv
# /kaggle/input/Mean_minmax_baseline/clean_week4/test/test_week4.csv
# /kaggle/input/Mean_minmax_baseline/clean_week4/train/clean_data_week4.csv
# /kaggle/input/Mean_minmax_baseline/clean_week4/train/5-folds/data_part_2.csv
# /kaggle/input/Mean_minmax_baseline/clean_week4/train/5-folds/data_part_3.csv
# /kaggle/input/Mean_minmax_baseline/clean_week4/train/5-folds/data_part_4.csv
# /kaggle/input/Mean_minmax_baseline/clean_week4/train/5-folds/data_part_1.csv
# /kaggle/input/Mean_minmax_baseline/clean_week4/train/5-folds/data_part_5.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_data_minmax_Fill-1.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week2/val/val_week1_2.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week2/test/test_week2.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week2/train/clean_data_week2.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week2/train/5-folds/data_part_2.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week2/train/5-folds/data_part_3.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week2/train/5-folds/data_part_4.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week2/train/5-folds/data_part_1.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week2/train/5-folds/data_part_5.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week3/val/val_week1_2_3.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week3/test/test_week3.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week3/train/clean_data_week3.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week3/train/5-folds/data_part_2.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week3/train/5-folds/data_part_3.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week3/train/5-folds/data_part_4.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week3/train/5-folds/data_part_1.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week3/train/5-folds/data_part_5.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week1/val/val_week1.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week1/test/test_week1.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week1/train/clean_data_week1.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week1/train/5-folds/data_part_2.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week1/train/5-folds/data_part_3.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week1/train/5-folds/data_part_4.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week1/train/5-folds/data_part_1.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week1/train/5-folds/data_part_5.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week4/val/val_week1_2_3_4.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week4/test/test_week4.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week4/train/clean_data_week4.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week4/train/5-folds/data_part_2.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week4/train/5-folds/data_part_3.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week4/train/5-folds/data_part_4.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week4/train/5-folds/data_part_1.csv
# /kaggle/input/Fill-1_minmax_baseline/clean_week4/train/5-folds/data_part_5.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_data_minmax_GCN_version3.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week2/val/val_week1_2.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week2/test/test_week2.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week2/train/clean_data_week2.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week2/train/5-folds/data_part_2.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week2/train/5-folds/data_part_3.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week2/train/5-folds/data_part_4.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week2/train/5-folds/data_part_1.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week2/train/5-folds/data_part_5.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week3/val/val_week1_2_3.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week3/test/test_week3.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week3/train/clean_data_week3.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week3/train/5-folds/data_part_2.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week3/train/5-folds/data_part_3.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week3/train/5-folds/data_part_4.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week3/train/5-folds/data_part_1.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week3/train/5-folds/data_part_5.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week1/val/val_week1.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week1/test/test_week1.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week1/train/clean_data_week1.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week1/train/5-folds/data_part_2.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week1/train/5-folds/data_part_3.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week1/train/5-folds/data_part_4.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week1/train/5-folds/data_part_1.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week1/train/5-folds/data_part_5.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week4/val/val_week1_2_3_4.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week4/test/test_week4.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week4/train/clean_data_week4.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week4/train/5-folds/data_part_2.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week4/train/5-folds/data_part_3.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week4/train/5-folds/data_part_4.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week4/train/5-folds/data_part_1.csv
# /kaggle/input/GCN_minmax_baseline_version3/clean_week4/train/5-folds/data_part_5.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_data_minmax_GCN.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week2/val/val_week1_2.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week2/test/test_week2.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week2/train/clean_data_week2.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week2/train/5-folds/data_part_2.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week2/train/5-folds/data_part_3.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week2/train/5-folds/data_part_4.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week2/train/5-folds/data_part_1.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week2/train/5-folds/data_part_5.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week3/val/val_week1_2_3.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week3/test/test_week3.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week3/train/clean_data_week3.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week3/train/5-folds/data_part_2.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week3/train/5-folds/data_part_3.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week3/train/5-folds/data_part_4.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week3/train/5-folds/data_part_1.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week3/train/5-folds/data_part_5.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week1/val/val_week1.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week1/test/test_week1.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week1/train/clean_data_week1.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week1/train/5-folds/data_part_2.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week1/train/5-folds/data_part_3.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week1/train/5-folds/data_part_4.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week1/train/5-folds/data_part_1.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week1/train/5-folds/data_part_5.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week4/val/val_week1_2_3_4.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week4/test/test_week4.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week4/train/clean_data_week4.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week4/train/5-folds/data_part_2.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week4/train/5-folds/data_part_3.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week4/train/5-folds/data_part_4.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week4/train/5-folds/data_part_1.csv
# /kaggle/input/GCN_minmax_baseline_version2/clean_week4/train/5-folds/data_part_5.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week2/val/val_week1_2.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week2/test/test_week2.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week2/train/clean_data_week2.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week2/train/5-folds/data_part_2.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week2/train/5-folds/data_part_3.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week2/train/5-folds/data_part_4.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week2/train/5-folds/data_part_1.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week2/train/5-folds/data_part_5.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week3/val/val_week1_2_3.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week3/test/test_week3.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week3/train/clean_data_week3.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week3/train/5-folds/data_part_2.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week3/train/5-folds/data_part_3.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week3/train/5-folds/data_part_4.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week3/train/5-folds/data_part_1.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week3/train/5-folds/data_part_5.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week1/val/val_week1.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week1/test/test_week1.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week1/train/clean_data_week1.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week1/train/5-folds/data_part_2.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week1/train/5-folds/data_part_3.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week1/train/5-folds/data_part_4.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week1/train/5-folds/data_part_1.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week1/train/5-folds/data_part_5.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week4/val/val_week1_2_3_4.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week4/test/test_week4.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week4/train/clean_data_week4.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week4/train/5-folds/data_part_2.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week4/train/5-folds/data_part_3.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week4/train/5-folds/data_part_4.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week4/train/5-folds/data_part_1.csv
# /kaggle/input/Median_minmax_baseline_version2/clean_week4/train/5-folds/data_part_5.csv
# /kaggle/input/Median_minmax_baseline/clean_week2/val/val_week1_2.csv
# /kaggle/input/Median_minmax_baseline/clean_week2/test/test_week2.csv
# /kaggle/input/Median_minmax_baseline/clean_week2/train/clean_data_week2.csv
# /kaggle/input/Median_minmax_baseline/clean_week2/train/5-folds/data_part_2.csv
# /kaggle/input/Median_minmax_baseline/clean_week2/train/5-folds/data_part_3.csv
# /kaggle/input/Median_minmax_baseline/clean_week2/train/5-folds/data_part_4.csv
# /kaggle/input/Median_minmax_baseline/clean_week2/train/5-folds/data_part_1.csv
# /kaggle/input/Median_minmax_baseline/clean_week2/train/5-folds/data_part_5.csv
# /kaggle/input/Median_minmax_baseline/clean_week3/val/val_week1_2_3.csv
# /kaggle/input/Median_minmax_baseline/clean_week3/test/test_week3.csv
# /kaggle/input/Median_minmax_baseline/clean_week3/train/clean_data_week3.csv
# /kaggle/input/Median_minmax_baseline/clean_week3/train/5-folds/data_part_2.csv
# /kaggle/input/Median_minmax_baseline/clean_week3/train/5-folds/data_part_3.csv
# /kaggle/input/Median_minmax_baseline/clean_week3/train/5-folds/data_part_4.csv
# /kaggle/input/Median_minmax_baseline/clean_week3/train/5-folds/data_part_1.csv
# /kaggle/input/Median_minmax_baseline/clean_week3/train/5-folds/data_part_5.csv
# /kaggle/input/Median_minmax_baseline/clean_week1/val/val_week1.csv
# /kaggle/input/Median_minmax_baseline/clean_week1/test/test_week1.csv
# /kaggle/input/Median_minmax_baseline/clean_week1/train/clean_data_week1.csv
# /kaggle/input/Median_minmax_baseline/clean_week1/train/5-folds/data_part_2.csv
# /kaggle/input/Median_minmax_baseline/clean_week1/train/5-folds/data_part_3.csv
# /kaggle/input/Median_minmax_baseline/clean_week1/train/5-folds/data_part_4.csv
# /kaggle/input/Median_minmax_baseline/clean_week1/train/5-folds/data_part_1.csv
# /kaggle/input/Median_minmax_baseline/clean_week1/train/5-folds/data_part_5.csv
# /kaggle/input/Median_minmax_baseline/clean_week4/val/val_week1_2_3_4.csv
# /kaggle/input/Median_minmax_baseline/clean_week4/test/test_week4.csv
# /kaggle/input/Median_minmax_baseline/clean_week4/train/clean_data_week4.csv
# /kaggle/input/Median_minmax_baseline/clean_week4/train/5-folds/data_part_2.csv
# /kaggle/input/Median_minmax_baseline/clean_week4/train/5-folds/data_part_3.csv
# /kaggle/input/Median_minmax_baseline/clean_week4/train/5-folds/data_part_4.csv
# /kaggle/input/Median_minmax_baseline/clean_week4/train/5-folds/data_part_1.csv
# /kaggle/input/Median_minmax_baseline/clean_week4/train/5-folds/data_part_5.csv
# /kaggle/input/KNN_minmax_baseline/clean_data_minmax_KNN.csv
# /kaggle/input/KNN_minmax_baseline/clean_week2/val/val_week1_2.csv
# /kaggle/input/KNN_minmax_baseline/clean_week2/test/test_week2.csv
# /kaggle/input/KNN_minmax_baseline/clean_week2/train/clean_data_week2.csv
# /kaggle/input/KNN_minmax_baseline/clean_week2/train/5-folds/data_part_2.csv
# /kaggle/input/KNN_minmax_baseline/clean_week2/train/5-folds/data_part_3.csv
# /kaggle/input/KNN_minmax_baseline/clean_week2/train/5-folds/data_part_4.csv
# /kaggle/input/KNN_minmax_baseline/clean_week2/train/5-folds/data_part_1.csv
# /kaggle/input/KNN_minmax_baseline/clean_week2/train/5-folds/data_part_5.csv
# /kaggle/input/KNN_minmax_baseline/clean_week3/val/val_week1_2_3.csv
# /kaggle/input/KNN_minmax_baseline/clean_week3/test/test_week3.csv
# /kaggle/input/KNN_minmax_baseline/clean_week3/train/clean_data_week3.csv
# /kaggle/input/KNN_minmax_baseline/clean_week3/train/5-folds/data_part_2.csv
# /kaggle/input/KNN_minmax_baseline/clean_week3/train/5-folds/data_part_3.csv
# /kaggle/input/KNN_minmax_baseline/clean_week3/train/5-folds/data_part_4.csv
# /kaggle/input/KNN_minmax_baseline/clean_week3/train/5-folds/data_part_1.csv
# /kaggle/input/KNN_minmax_baseline/clean_week3/train/5-folds/data_part_5.csv
# /kaggle/input/KNN_minmax_baseline/clean_week1/val/val_week1.csv
# /kaggle/input/KNN_minmax_baseline/clean_week1/test/test_week1.csv
# /kaggle/input/KNN_minmax_baseline/clean_week1/train/clean_data_week1.csv
# /kaggle/input/KNN_minmax_baseline/clean_week1/train/5-folds/data_part_2.csv
# /kaggle/input/KNN_minmax_baseline/clean_week1/train/5-folds/data_part_3.csv
# /kaggle/input/KNN_minmax_baseline/clean_week1/train/5-folds/data_part_4.csv
# /kaggle/input/KNN_minmax_baseline/clean_week1/train/5-folds/data_part_1.csv
# /kaggle/input/KNN_minmax_baseline/clean_week1/train/5-folds/data_part_5.csv
# /kaggle/input/KNN_minmax_baseline/clean_week4/val/val_week1_2_3_4.csv
# /kaggle/input/KNN_minmax_baseline/clean_week4/test/test_week4.csv
# /kaggle/input/KNN_minmax_baseline/clean_week4/train/clean_data_week4.csv
# /kaggle/input/KNN_minmax_baseline/clean_week4/train/5-folds/data_part_2.csv
# /kaggle/input/KNN_minmax_baseline/clean_week4/train/5-folds/data_part_3.csv
# /kaggle/input/KNN_minmax_baseline/clean_week4/train/5-folds/data_part_4.csv
# /kaggle/input/KNN_minmax_baseline/clean_week4/train/5-folds/data_part_1.csv
# /kaggle/input/KNN_minmax_baseline/clean_week4/train/5-folds/data_part_5.csv
# /kaggle/input/new_raw/raw_data/clean_week2/val/val_week1_2.csv
# /kaggle/input/new_raw/raw_data/clean_week2/test/test_week2.csv
# /kaggle/input/new_raw/raw_data/clean_week2/train/clean_data_week2.csv
# /kaggle/input/new_raw/raw_data/clean_week2/train/5-folds/data_part_2.csv
# /kaggle/input/new_raw/raw_data/clean_week2/train/5-folds/data_part_3.csv
# /kaggle/input/new_raw/raw_data/clean_week2/train/5-folds/data_part_4.csv
# /kaggle/input/new_raw/raw_data/clean_week2/train/5-folds/data_part_1.csv
# /kaggle/input/new_raw/raw_data/clean_week2/train/5-folds/data_part_5.csv
# /kaggle/input/new_raw/raw_data/clean_week3/val/val_week1_2_3.csv
# /kaggle/input/new_raw/raw_data/clean_week3/test/test_week3.csv
# /kaggle/input/new_raw/raw_data/clean_week3/train/clean_data_week3.csv
# /kaggle/input/new_raw/raw_data/clean_week3/train/5-folds/data_part_2.csv
# /kaggle/input/new_raw/raw_data/clean_week3/train/5-folds/data_part_3.csv
# /kaggle/input/new_raw/raw_data/clean_week3/train/5-folds/data_part_4.csv
# /kaggle/input/new_raw/raw_data/clean_week3/train/5-folds/data_part_1.csv
# /kaggle/input/new_raw/raw_data/clean_week3/train/5-folds/data_part_5.csv
# /kaggle/input/new_raw/raw_data/clean_week1/val/val_week1.csv
# /kaggle/input/new_raw/raw_data/clean_week1/test/test_week1.csv
# /kaggle/input/new_raw/raw_data/clean_week1/train/clean_data_week1.csv
# /kaggle/input/new_raw/raw_data/clean_week1/train/5-folds/data_part_2.csv
# /kaggle/input/new_raw/raw_data/clean_week1/train/5-folds/data_part_3.csv
# /kaggle/input/new_raw/raw_data/clean_week1/train/5-folds/data_part_4.csv
# /kaggle/input/new_raw/raw_data/clean_week1/train/5-folds/data_part_1.csv
# /kaggle/input/new_raw/raw_data/clean_week1/train/5-folds/data_part_5.csv
# /kaggle/input/new_raw/raw_data/clean_week4/val/val_week1_2_3_4.csv
# /kaggle/input/new_raw/raw_data/clean_week4/test/test_week4.csv
# /kaggle/input/new_raw/raw_data/clean_week4/train/clean_data_week4.csv
# /kaggle/input/new_raw/raw_data/clean_week4/train/5-folds/data_part_2.csv
# /kaggle/input/new_raw/raw_data/clean_week4/train/5-folds/data_part_3.csv
# /kaggle/input/new_raw/raw_data/clean_week4/train/5-folds/data_part_4.csv
# /kaggle/input/new_raw/raw_data/clean_week4/train/5-folds/data_part_1.csv
# /kaggle/input/new_raw/raw_data/clean_week4/train/5-folds/data_part_5.csv
# /kaggle/input/new_raw/clean_data/clean_week2/val/val_week1_2.csv
# /kaggle/input/new_raw/clean_data/clean_week2/test/test_week2.csv
# /kaggle/input/new_raw/clean_data/clean_week2/train/clean_data_week2.csv
# /kaggle/input/new_raw/clean_data/clean_week2/train/5-folds/data_part_2.csv
# /kaggle/input/new_raw/clean_data/clean_week2/train/5-folds/data_part_3.csv
# /kaggle/input/new_raw/clean_data/clean_week2/train/5-folds/data_part_4.csv
# /kaggle/input/new_raw/clean_data/clean_week2/train/5-folds/data_part_1.csv
# /kaggle/input/new_raw/clean_data/clean_week2/train/5-folds/data_part_5.csv
# /kaggle/input/new_raw/clean_data/clean_week3/val/val_week1_2_3.csv
# /kaggle/input/new_raw/clean_data/clean_week3/test/test_week3.csv
# /kaggle/input/new_raw/clean_data/clean_week3/train/clean_data_week3.csv
# /kaggle/input/new_raw/clean_data/clean_week3/train/5-folds/data_part_2.csv
# /kaggle/input/new_raw/clean_data/clean_week3/train/5-folds/data_part_3.csv
# /kaggle/input/new_raw/clean_data/clean_week3/train/5-folds/data_part_4.csv
# /kaggle/input/new_raw/clean_data/clean_week3/train/5-folds/data_part_1.csv
# /kaggle/input/new_raw/clean_data/clean_week3/train/5-folds/data_part_5.csv
# /kaggle/input/new_raw/clean_data/clean_week1/val/val_week1.csv
# /kaggle/input/new_raw/clean_data/clean_week1/test/test_week1.csv
# /kaggle/input/new_raw/clean_data/clean_week1/train/clean_data_week1.csv
# /kaggle/input/new_raw/clean_data/clean_week1/train/5-folds/data_part_2.csv
# /kaggle/input/new_raw/clean_data/clean_week1/train/5-folds/data_part_3.csv
# /kaggle/input/new_raw/clean_data/clean_week1/train/5-folds/data_part_4.csv
# /kaggle/input/new_raw/clean_data/clean_week1/train/5-folds/data_part_1.csv
# /kaggle/input/new_raw/clean_data/clean_week1/train/5-folds/data_part_5.csv
# /kaggle/input/new_raw/clean_data/clean_week4/val/val_week1_2_3_4.csv
# /kaggle/input/new_raw/clean_data/clean_week4/test/test_week4.csv
# /kaggle/input/new_raw/clean_data/clean_week4/train/clean_data_week4.csv
# /kaggle/input/new_raw/clean_data/clean_week4/train/5-folds/data_part_2.csv
# /kaggle/input/new_raw/clean_data/clean_week4/train/5-folds/data_part_3.csv
# /kaggle/input/new_raw/clean_data/clean_week4/train/5-folds/data_part_4.csv
# /kaggle/input/new_raw/clean_data/clean_week4/train/5-folds/data_part_1.csv
# /kaggle/input/new_raw/clean_data/clean_week4/train/5-folds/data_part_5.csv

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import backend as K
from kerastuner.tuners import RandomSearch
from sklearn.model_selection import StratifiedKFold
import time
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_recall_fscore_support, roc_auc_score
# Out:
# <ipython-input-2-63192117ceec>:7: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.tuners import RandomSearch

# %%
# Biến global cho base path
BASE_PATH = "/kaggle/input/GCN_minmax_baseline_version4"
# Tuần và số phần fold
weeks = ['week1', 'week2', 'week3', 'week4']
fold_parts = 5

# Tạo five_fold_files
five_fold_files = {
    week: [
        f"{BASE_PATH}/clean_{week}/train/5-folds/data_part_{i}.csv"
        for i in range(1, fold_parts + 1)
    ]
    for week in weeks
}

# Tạo file_validation
file_validation = {
    'week1': [f"{BASE_PATH}/clean_week1/val/val_week1.csv"],
    'week2': [f"{BASE_PATH}/clean_week2/val/val_week1_2.csv"],
    'week3': [f"{BASE_PATH}/clean_week3/val/val_week1_2_3.csv"],
    'week4': [f"{BASE_PATH}/clean_week4/val/val_week1_2_3_4.csv"]
}

# Tạo file_test
file_test = {
    week: [f"{BASE_PATH}/clean_{week}/test/test_{week}.csv"]
    for week in weeks
}

# %%
# Định nghĩa Focal Loss
def focal_loss(gamma=2., alpha=0.25):
    def focal_loss_fixed(y_true, y_pred):
        y_pred = K.clip(y_pred, K.epsilon(), 1. - K.epsilon())
        cross_entropy = -y_true * K.log(y_pred)
        loss = alpha * K.pow(1 - y_pred, gamma) * cross_entropy
        return K.sum(loss, axis=-1)
    return focal_loss_fixed

# Tạo hàm train cho từng tuần
def train_week_model(week_number, file_paths_train, file_validataion):
   # Đọc dữ liệu
    train_data = pd.read_csv(file_paths_train)
    val_data = pd.read_csv(file_validataion)
    
    # Tách đặc trưng và nhãn
    X_train = train_data.drop(columns=["classification_encoded", "user_id", "course_id", "school", "enroll_time", "classification"])
    y_train = train_data["classification_encoded"]

    X_val = val_data.drop(columns=["classification_encoded", "user_id", "course_id", "school", "enroll_time", "classification"])
    y_val = val_data["classification_encoded"]
    

    # Áp dụng Over-sampling cho dữ liệu huấn luyện bằng SMOTE
    oversampler = SMOTE(sampling_strategy='auto', random_state=42)
    X_train_res, y_train_res = oversampler.fit_resample(X_train, y_train)

    # One-hot encode nhãn
    y_train_res = tf.keras.utils.to_categorical(y_train_res, num_classes=5)
    y_val = tf.keras.utils.to_categorical(y_val, num_classes=5)

    # Xây dựng mô hình 4-layer stacked LSTM
    def build_model(hp):
        model = tf.keras.Sequential()
        
        # LSTM layer 1
        model.add(layers.LSTM(
            units=hp.Int('units_1', min_value=32, max_value=256, step=32),
            return_sequences=True,
            input_shape=(X_train_res.shape[1], 1)
        ))
        model.add(layers.Dropout(rate=hp.Float('dropout_1', min_value=0.1, max_value=0.5, step=0.1)))
        
        # LSTM layer 2
        model.add(layers.LSTM(
            units=hp.Int('units_2', min_value=32, max_value=256, step=32),
            return_sequences=True
        ))
        model.add(layers.Dropout(rate=hp.Float('dropout_2', min_value=0.1, max_value=0.5, step=0.1)))
        
        # LSTM layer 3
        model.add(layers.LSTM(
            units=hp.Int('units_3', min_value=32, max_value=256, step=32),
            return_sequences=True
        ))
        model.add(layers.Dropout(rate=hp.Float('dropout_3', min_value=0.1, max_value=0.5, step=0.1)))
        
        # LSTM layer 4
        model.add(layers.LSTM(
            units=hp.Int('units_4', min_value=32, max_value=256, step=32),
            return_sequences=False
        ))
        model.add(layers.Dropout(rate=hp.Float('dropout_4', min_value=0.1, max_value=0.5, step=0.1)))

        # Lớp đầu ra
        model.add(layers.Dense(5, activation='softmax'))

        # Compile với Focal Loss
        model.compile(optimizer=tf.keras.optimizers.Adam(
                          learning_rate=hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='LOG')),
                      loss=focal_loss(gamma=2., alpha=0.25),
                      metrics=['accuracy'])
        return model

    # Khởi tạo RandomSearch tuner
    tuner = RandomSearch(
        build_model,
        objective='val_accuracy',
        max_trials=10,
        executions_per_trial=1,
        directory='my_dir',
        project_name=f'lstm_tuning_week{week_number}'
    )

    # Tìm kiếm siêu tham số tốt nhất
    tuner.search(X_train_res, y_train_res,
                 epochs=20,
                 validation_data=(X_val, y_val),
                 batch_size=32)

    # Trả về kết quả tối ưu cho tuần
    best_params = tuner.get_best_hyperparameters(num_trials=1)[0]
    return best_params

# %%
# Định nghĩa đường dẫn đến dữ liệu cho từng tuần
file_paths_train = {
    week: f"{BASE_PATH}/clean_{week}/train/clean_data_{week}.csv"
    for week in weeks
}

# Định nghĩa file_validation theo quy luật riêng
file_validation = {
    f"week{idx + 1}": f"{BASE_PATH}/clean_week{idx + 1}/val/val_week{'_'.join(str(i) for i in range(1, idx + 2))}.csv"
    for idx in range(len(weeks))
}

# %%
# Tìm tham số tốt nhất cho từng tuần
best_params_week1 = train_week_model(1, file_paths_train["week1"], file_validation["week1"])
best_params_week2 = train_week_model(2, file_paths_train["week2"], file_validation["week2"])
best_params_week3 = train_week_model(3, file_paths_train["week3"], file_validation["week3"])
best_params_week4 = train_week_model(4, file_paths_train["week4"], file_validation["week4"])

# In thông tin chi tiết các tham số tối ưu
print("Best Parameters for Week 1:")
for param_name in best_params_week1.values.keys():
    print(f"{param_name}: {best_params_week1.get(param_name)}")

print("\nBest Parameters for Week 2:")
for param_name in best_params_week2.values.keys():
    print(f"{param_name}: {best_params_week2.get(param_name)}")

print("\nBest Parameters for Week 3:")
for param_name in best_params_week3.values.keys():
    print(f"{param_name}: {best_params_week3.get(param_name)}")

print("\nBest Parameters for Week 4:")
for param_name in best_params_week4.values.keys():
    print(f"{param_name}: {best_params_week4.get(param_name)}")
# Out:
# Trial 10 Complete [00h 04m 24s]
# val_accuracy: 0.9938986897468567
#
# Best val_accuracy So Far: 0.9938986897468567
# Total elapsed time: 00h 44m 41s
# Best Parameters for Week 1:
# units_1: 32
# dropout_1: 0.5
# units_2: 32
# dropout_2: 0.30000000000000004
# units_3: 128
# dropout_3: 0.2
# units_4: 256
# dropout_4: 0.1
# learning_rate: 0.0017649674278631807
#
# Best Parameters for Week 2:
# units_1: 160
# dropout_1: 0.2
# units_2: 160
# dropout_2: 0.5
# units_3: 96
# dropout_3: 0.5
# units_4: 192
# dropout_4: 0.1
# learning_rate: 0.0014789571342550213
#
# Best Parameters for Week 3:
# units_1: 224
# dropout_1: 0.30000000000000004
# units_2: 192
# dropout_2: 0.1
# units_3: 128
# dropout_3: 0.30000000000000004
# units_4: 128
# dropout_4: 0.30000000000000004
# learning_rate: 0.0029973497945481892
#
# Best Parameters for Week 4:
# units_1: 64
# dropout_1: 0.2
# units_2: 96
# dropout_2: 0.2
# units_3: 192
# dropout_3: 0.5
# units_4: 256
# dropout_4: 0.2
# learning_rate: 0.005529023837534512

# %%
# Danh sách tham số tốt nhất
best_params = {
    "week1": best_params_week1,
    "week2": best_params_week2,
    "week3": best_params_week3,
    "week4": best_params_week4
}

# %%
from tensorflow.keras import layers
import tensorflow as tf
from tensorflow.keras import backend as K

# Định nghĩa Focal Loss
def focal_loss(gamma=2., alpha=0.25):
    def focal_loss_fixed(y_true, y_pred):
        y_pred = K.clip(y_pred, K.epsilon(), 1. - K.epsilon())
        cross_entropy = -y_true * K.log(y_pred)
        loss = alpha * K.pow(1 - y_pred, gamma) * cross_entropy
        return K.sum(loss, axis=-1)
    
    return focal_loss_fixed

# Xây dựng mô hình
def build_lstm_model(params):
    model = tf.keras.Sequential()
    
    # LSTM layer 1
    model.add(layers.LSTM(
        units=params.get('units_1', 32),
        return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2]))
    )
    model.add(layers.Dropout(rate=params.get('dropout_1', 0.2)))

    # LSTM layer 2
    model.add(layers.LSTM(
        units=params.get('units_2', 32),
        return_sequences=True
    ))
    model.add(layers.Dropout(rate=params.get('dropout_2', 0.2)))

    # LSTM layer 3
    model.add(layers.LSTM(
        units=params.get('units_3', 32),
        return_sequences=True
    ))
    model.add(layers.Dropout(rate=params.get('dropout_3', 0.2)))

    # LSTM layer 4
    model.add(layers.LSTM(
        units=params.get('units_4', 32),
        return_sequences=False
    ))
    model.add(layers.Dropout(rate=params.get('dropout_4', 0.2)))

    # Output layer
    model.add(layers.Dense(5, activation='softmax'))  # 5 classes in output

    # Compile the model
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=params['learning_rate']),
        loss=focal_loss(gamma=params.get('gamma', 2.), alpha=params.get('alpha', 0.25)),
        metrics=['accuracy']
    )
    
    return model

# %%
# Biến lưu kết quả tổng quát
overall_results_5folds = []

# Lặp qua từng tuần
for week, file_paths in five_fold_files.items():
    print(f"\nProcessing {week} with best parameters...")
    params = best_params[week].values
    print(f"best parameters for {week}: {params}")
    
    # Biến lưu kết quả cho từng tuần
    week_results = {
        "week": week,
        "accuracy_per_fold": [],
        "precision_per_label": [],
        "recall_per_label": [],
        "f1_score_per_label": [],
        "auc_roc_per_label": [],    # AUC từng lớp
        "auc_roc_macro": [],        # AUC macro
        "auc_roc_weighted": [],     # AUC weighted (tự tính)
        "precision_macro": [],
        "recall_macro": [],
        "f1_macro": [],
        "precision_weighted": [],
        "recall_weighted": [],
        "f1_weighted": [],
        "confusion_matrices": [],
        "train_times": [],
        "test_times": []
    }

    # Lặp qua từng fold
    for i in range(len(file_paths)):
        print(f"Fold {i+1}: Using file {file_paths[i]} as test set")
        
        # Tải dữ liệu
        test_data = pd.read_csv(file_paths[i])
        train_data = pd.concat([pd.read_csv(file_paths[j]) for j in range(len(file_paths)) if j != i])
        
        # Tách X và y
        X_train = train_data.drop(columns=["classification_encoded", "user_id",
                                           "course_id", "school", "enroll_time", "classification"])
        y_train = to_categorical(train_data['classification_encoded'], num_classes=5)
        
        X_test = test_data.drop(columns=["classification_encoded", "user_id",
                                         "course_id", "school", "enroll_time", "classification"])
        y_test = to_categorical(test_data['classification_encoded'], num_classes=5)

        # Reshape dữ liệu cho LSTM
        X_train = X_train.to_numpy().reshape((X_train.shape[0], 1, X_train.shape[1]))
        X_test = X_test.to_numpy().reshape((X_test.shape[0], 1, X_test.shape[1]))

        # Xây dựng mô hình với tham số tốt nhất
        model = build_lstm_model(params)
        
        # Bắt đầu tính thời gian huấn luyện
        start_train = time.time()
        model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test), batch_size=32)
        end_train = time.time()
        
        # Bắt đầu tính thời gian kiểm thử
        start_test = time.time()
        y_pred = model.predict(X_test)
        end_test = time.time()
        
        # Tính thời gian và lưu lại
        train_time = end_train - start_train
        test_time = end_test - start_test
        week_results["train_times"].append(train_time)
        week_results["test_times"].append(test_time)

        # Đánh giá mô hình trên tập kiểm thử của fold hiện tại
        _, accuracy = model.evaluate(X_test, y_test, verbose=0)
        week_results["accuracy_per_fold"].append(accuracy)
        
        # Dự đoán
        y_pred_classes = y_pred.argmax(axis=1)
        y_test_classes = y_test.argmax(axis=1)
        
        # Tính các chỉ số cho mỗi fold
        precision, recall, f1, _ = precision_recall_fscore_support(y_test_classes, y_pred_classes, average=None)
        precision_macro, recall_macro, f1_macro, _ = precision_recall_fscore_support(y_test_classes, y_pred_classes, average='macro')
        precision_weighted, recall_weighted, f1_weighted, _ = precision_recall_fscore_support(y_test_classes, y_pred_classes, average='weighted')
        conf_matrix = confusion_matrix(y_test_classes, y_pred_classes)
        
        # Tính AUC-ROC
        try:
            # Tính AUC macro và theo từng lớp với OvR
            auc_macro = roc_auc_score(y_test, y_pred, multi_class="ovr", average="macro")
            auc_per_class = roc_auc_score(y_test, y_pred, multi_class="ovr", average=None)
            # Tính AUC weighted: tính trọng số theo số mẫu của từng lớp
            supports = np.bincount(y_test_classes, minlength=5)
            auc_weighted = np.sum(auc_per_class * supports) / np.sum(supports)
        except Exception as e:
            print(f"Lỗi khi tính AUC: {e}")
            auc_macro = np.nan
            auc_per_class = [np.nan] * 5
            auc_weighted = np.nan
            
        # Lưu kết quả của fold hiện tại
        week_results["precision_per_label"].append(precision)
        week_results["recall_per_label"].append(recall)
        week_results["f1_score_per_label"].append(f1)
        week_results["auc_roc_per_label"].append(auc_per_class)  # AUC từng lớp
        week_results["auc_roc_macro"].append(auc_macro)          # AUC macro
        week_results["auc_roc_weighted"].append(auc_weighted)      # AUC weighted
        week_results["confusion_matrices"].append(conf_matrix)
        week_results["precision_macro"].append(precision_macro)
        week_results["recall_macro"].append(recall_macro)
        week_results["f1_macro"].append(f1_macro)
        week_results["precision_weighted"].append(precision_weighted)
        week_results["recall_weighted"].append(recall_weighted)
        week_results["f1_weighted"].append(f1_weighted)

    # Tính trung bình cho từng nhãn
    average_precision_per_label = np.mean(week_results["precision_per_label"], axis=0)
    average_recall_per_label = np.nanmean(week_results["recall_per_label"], axis=0)
    average_f1_per_label = np.nanmean(week_results["f1_score_per_label"], axis=0)
    average_auc_per_label = np.nanmean(week_results["auc_roc_per_label"], axis=0)
    average_confusion_matrix = np.nanmean(week_results["confusion_matrices"], axis=0)
    average_train_time = sum(week_results["train_times"]) / len(week_results["train_times"])
    average_test_time = sum(week_results["test_times"]) / len(week_results["test_times"])
    average_accuracy = np.nanmean(week_results["accuracy_per_fold"])
    average_precision_macro = np.nanmean(week_results["precision_macro"])
    average_recall_macro = np.nanmean(week_results["recall_macro"])
    average_f1_macro = np.nanmean(week_results["f1_macro"])
    average_auc_macro = np.nanmean(week_results["auc_roc_macro"])
    average_precision_weighted = np.nanmean(week_results["precision_weighted"])
    average_recall_weighted = np.nanmean(week_results["recall_weighted"])
    average_f1_weighted = np.nanmean(week_results["f1_weighted"])
    average_auc_weighted = np.nanmean(week_results["auc_roc_weighted"])


    # Tạo DataFrame cho precision, recall, f1-score
    labels = np.unique(y_test_classes)  # Lấy nhãn từ y_test_classes
    metrics_df = pd.DataFrame({
        "Label": labels,
        "Average Precision": average_precision_per_label,
        "Average Recall": average_recall_per_label,
        "Average F1-Score": average_f1_per_label,
        "Average AUC": average_auc_per_label
    })
    
    # Tạo DataFrame cho confusion matrix
    confusion_df = pd.DataFrame(average_confusion_matrix, index=labels, columns=labels)
    # In kết quả Accuracy và Macro metrics
    print("\n=== Average Accuracy ===")
    print(f"{average_accuracy:.4f}")
    print("\n=== Average Macro Metrics ===")
    print(f"Macro Precision: {average_precision_macro:.4f}")
    print(f"Macro Recall: {average_recall_macro:.4f}")
    print(f"Macro F1-Score: {average_f1_macro:.4f}")
    print(f"Macro AUC-ROC: {average_auc_macro:.4f}")
    print("\n=== Average Weighted Metrics ===")
    print(f"Weighted Precision: {average_precision_weighted:.4f}")
    print(f"Weighted Recall: {average_recall_weighted:.4f}")
    print(f"Weighted F1-Score: {average_f1_weighted:.4f}")
    print(f"Weighted AUC-ROC: {average_auc_weighted:.4f}")
    print("\n=== Average Metrics per Label ===")
    print(metrics_df)
    print("\n=== Average Confusion Matrix ===")
    print(confusion_df)
    
    # Cập nhật kết quả cho tuần hiện tại
    week_results.update({
        "average_accuracy": average_accuracy,
        "average_precision_macro": average_precision_macro,
        "average_recall_macro": average_recall_macro,
        "average_f1_macro": average_f1_macro,
        "average_auc_macro": average_auc_macro,
        "average_precision_weighted": average_precision_weighted,
        "average_recall_weighted": average_recall_weighted,
        "average_f1_weighted": average_f1_weighted,
        "average_auc_weighted": average_auc_weighted,
        "average_metrics_df": metrics_df,
        "average_confusion_matrix": confusion_df,
        "average_train_times": average_train_time,
        "average_test_times": average_test_time,
    })
    overall_results_5folds.append(week_results)
# Out:
# Processing week1 with best parameters...
# best parameters for week1: {'units_1': 32, 'dropout_1': 0.5, 'units_2': 32, 'dropout_2': 0.30000000000000004, 'units_3': 128, 'dropout_3': 0.2, 'units_4': 256, 'dropout_4': 0.1, 'learning_rate': 0.0017649674278631807}
# Fold 1: Using file /kaggle/input/GCN_minmax_baseline_version4/clean_week1/train/5-folds/data_part_1.csv as test set
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.6003 - loss: 0.1644 - val_accuracy: 0.6256 - val_loss: 0.1272
# Epoch 2/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6441 - loss: 0.1324 - val_accuracy: 0.6424 - val_loss: 0.1215
# Epoch 3/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6483 - loss: 0.1273 - val_accuracy: 0.6820 - val_loss: 0.1158
# Epoch 4/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6573 - loss: 0.1245 - val_accuracy: 0.6866 - val_loss: 0.1111
# Epoch 5/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6607 - loss: 0.1234 - val_accuracy: 0.6958 - val_loss: 0.1092
# Epoch 6/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6744 - loss: 0.1224 - val_accuracy: 0.7205 - val_loss: 0.1052
# Epoch 7/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6717 - loss: 0.1171 - val_accuracy: 0.7160 - val_loss: 0.1064
# Epoch 8/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6805 - loss: 0.1184 - val_accuracy: 0.7099 - val_loss: 0.1044
# Epoch 9/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6860 - loss: 0.1147 - val_accuracy: 0.7263 - val_loss: 0.1063
# Epoch 10/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6953 - loss: 0.1147 - val_accuracy: 0.6988 - val_loss: 0.1060
# Epoch 11/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6824 - loss: 0.1139 - val_accuracy: 0.7480 - val_loss: 0.1001
# Epoch 12/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6942 - loss: 0.1140 - val_accuracy: 0.7251 - val_loss: 0.1010
# Epoch 13/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6953 - loss: 0.1130 - val_accuracy: 0.7263 - val_loss: 0.1022
# Epoch 14/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6941 - loss: 0.1135 - val_accuracy: 0.7381 - val_loss: 0.0988
# Epoch 15/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7051 - loss: 0.1117 - val_accuracy: 0.7327 - val_loss: 0.1016
# Epoch 16/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6986 - loss: 0.1106 - val_accuracy: 0.7480 - val_loss: 0.0970
# Epoch 17/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7035 - loss: 0.1116 - val_accuracy: 0.7232 - val_loss: 0.1006
# Epoch 18/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6966 - loss: 0.1133 - val_accuracy: 0.7373 - val_loss: 0.0991
# Epoch 19/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7000 - loss: 0.1119 - val_accuracy: 0.7320 - val_loss: 0.0983
# Epoch 20/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7109 - loss: 0.1093 - val_accuracy: 0.7369 - val_loss: 0.1000
# Epoch 21/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7177 - loss: 0.1077 - val_accuracy: 0.7362 - val_loss: 0.0971
# Epoch 22/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7173 - loss: 0.1088 - val_accuracy: 0.7339 - val_loss: 0.0977
# Epoch 23/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7136 - loss: 0.1071 - val_accuracy: 0.7465 - val_loss: 0.0952
# Epoch 24/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7121 - loss: 0.1040 - val_accuracy: 0.7419 - val_loss: 0.0948
# Epoch 25/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7199 - loss: 0.1079 - val_accuracy: 0.7396 - val_loss: 0.0991
# Epoch 26/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7157 - loss: 0.1087 - val_accuracy: 0.7621 - val_loss: 0.0938
# Epoch 27/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7113 - loss: 0.1085 - val_accuracy: 0.7617 - val_loss: 0.0937
# Epoch 28/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7133 - loss: 0.1090 - val_accuracy: 0.7587 - val_loss: 0.0946
# Epoch 29/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7200 - loss: 0.1082 - val_accuracy: 0.7560 - val_loss: 0.0944
# Epoch 30/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7134 - loss: 0.1064 - val_accuracy: 0.7632 - val_loss: 0.0917
# Epoch 31/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7207 - loss: 0.1052 - val_accuracy: 0.7652 - val_loss: 0.0901
# Epoch 32/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7307 - loss: 0.1035 - val_accuracy: 0.7644 - val_loss: 0.0931
# Epoch 33/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7215 - loss: 0.1062 - val_accuracy: 0.7522 - val_loss: 0.0940
# Epoch 34/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7235 - loss: 0.1049 - val_accuracy: 0.7674 - val_loss: 0.0918
# Epoch 35/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7200 - loss: 0.1059 - val_accuracy: 0.7545 - val_loss: 0.0973
# Epoch 36/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7188 - loss: 0.1064 - val_accuracy: 0.7583 - val_loss: 0.0929
# Epoch 37/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7181 - loss: 0.1092 - val_accuracy: 0.7571 - val_loss: 0.0956
# Epoch 38/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7193 - loss: 0.1056 - val_accuracy: 0.7716 - val_loss: 0.0884
# Epoch 39/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7309 - loss: 0.1039 - val_accuracy: 0.7659 - val_loss: 0.0887
# Epoch 40/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7298 - loss: 0.1037 - val_accuracy: 0.7690 - val_loss: 0.0887
# Epoch 41/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7261 - loss: 0.1051 - val_accuracy: 0.7667 - val_loss: 0.0904
# Epoch 42/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7269 - loss: 0.1020 - val_accuracy: 0.7549 - val_loss: 0.0900
# Epoch 43/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7362 - loss: 0.1015 - val_accuracy: 0.7667 - val_loss: 0.0924
# Epoch 44/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7380 - loss: 0.0998 - val_accuracy: 0.7796 - val_loss: 0.0877
# Epoch 45/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7290 - loss: 0.1016 - val_accuracy: 0.7846 - val_loss: 0.0852
# Epoch 46/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7290 - loss: 0.1024 - val_accuracy: 0.7587 - val_loss: 0.0893
# Epoch 47/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7215 - loss: 0.1069 - val_accuracy: 0.7693 - val_loss: 0.0877
# Epoch 48/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7343 - loss: 0.1015 - val_accuracy: 0.7549 - val_loss: 0.0911
# Epoch 49/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7249 - loss: 0.1028 - val_accuracy: 0.7636 - val_loss: 0.0890
# Epoch 50/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7464 - loss: 0.0971 - val_accuracy: 0.7789 - val_loss: 0.0884
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Fold 2: Using file /kaggle/input/GCN_minmax_baseline_version4/clean_week1/train/5-folds/data_part_2.csv as test set
# Epoch 1/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.6078 - loss: 0.1632 - val_accuracy: 0.6142 - val_loss: 0.1334
# Epoch 2/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6130 - loss: 0.1354 - val_accuracy: 0.6271 - val_loss: 0.1228
# Epoch 3/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6400 - loss: 0.1269 - val_accuracy: 0.6233 - val_loss: 0.1159
# Epoch 4/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6355 - loss: 0.1238 - val_accuracy: 0.6260 - val_loss: 0.1142
# Epoch 5/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6503 - loss: 0.1208 - val_accuracy: 0.7038 - val_loss: 0.1132
# Epoch 6/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6724 - loss: 0.1169 - val_accuracy: 0.7106 - val_loss: 0.1103
# Epoch 7/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6571 - loss: 0.1204 - val_accuracy: 0.7186 - val_loss: 0.1062
# Epoch 8/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6827 - loss: 0.1137 - val_accuracy: 0.7244 - val_loss: 0.1075
# Epoch 9/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6790 - loss: 0.1133 - val_accuracy: 0.7339 - val_loss: 0.1043
# Epoch 10/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6966 - loss: 0.1129 - val_accuracy: 0.7339 - val_loss: 0.1031
# Epoch 11/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7019 - loss: 0.1108 - val_accuracy: 0.7305 - val_loss: 0.1041
# Epoch 12/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6955 - loss: 0.1123 - val_accuracy: 0.7274 - val_loss: 0.1026
# Epoch 13/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6945 - loss: 0.1126 - val_accuracy: 0.7583 - val_loss: 0.1024
# Epoch 14/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7003 - loss: 0.1104 - val_accuracy: 0.7560 - val_loss: 0.1017
# Epoch 15/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6930 - loss: 0.1134 - val_accuracy: 0.7396 - val_loss: 0.1038
# Epoch 16/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6989 - loss: 0.1116 - val_accuracy: 0.7144 - val_loss: 0.1022
# Epoch 17/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6894 - loss: 0.1098 - val_accuracy: 0.7606 - val_loss: 0.1021
# Epoch 18/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7031 - loss: 0.1101 - val_accuracy: 0.7175 - val_loss: 0.1049
# Epoch 19/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6978 - loss: 0.1123 - val_accuracy: 0.7610 - val_loss: 0.0990
# Epoch 20/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7039 - loss: 0.1085 - val_accuracy: 0.6847 - val_loss: 0.1092
# Epoch 21/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6961 - loss: 0.1084 - val_accuracy: 0.7671 - val_loss: 0.0974
# Epoch 22/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7121 - loss: 0.1077 - val_accuracy: 0.7594 - val_loss: 0.0994
# Epoch 23/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7085 - loss: 0.1057 - val_accuracy: 0.7408 - val_loss: 0.0993
# Epoch 24/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7141 - loss: 0.1056 - val_accuracy: 0.7610 - val_loss: 0.0963
# Epoch 25/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7169 - loss: 0.1047 - val_accuracy: 0.7514 - val_loss: 0.0965
# Epoch 26/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7082 - loss: 0.1086 - val_accuracy: 0.7697 - val_loss: 0.1016
# Epoch 27/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7125 - loss: 0.1103 - val_accuracy: 0.7571 - val_loss: 0.0990
# Epoch 28/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7196 - loss: 0.1034 - val_accuracy: 0.7430 - val_loss: 0.1035
# Epoch 29/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7085 - loss: 0.1083 - val_accuracy: 0.7774 - val_loss: 0.0960
# Epoch 30/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7190 - loss: 0.1035 - val_accuracy: 0.7659 - val_loss: 0.0934
# Epoch 31/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7275 - loss: 0.1052 - val_accuracy: 0.7678 - val_loss: 0.0953
# Epoch 32/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7192 - loss: 0.1051 - val_accuracy: 0.7751 - val_loss: 0.0949
# Epoch 33/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7205 - loss: 0.1063 - val_accuracy: 0.7690 - val_loss: 0.0981
# Epoch 34/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7272 - loss: 0.1051 - val_accuracy: 0.7613 - val_loss: 0.0992
# Epoch 35/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7281 - loss: 0.1029 - val_accuracy: 0.7537 - val_loss: 0.0965
# Epoch 36/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7220 - loss: 0.1079 - val_accuracy: 0.7785 - val_loss: 0.0970
# Epoch 37/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7311 - loss: 0.1010 - val_accuracy: 0.7613 - val_loss: 0.0968
# Epoch 38/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7135 - loss: 0.1071 - val_accuracy: 0.7842 - val_loss: 0.0958
# Epoch 39/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7175 - loss: 0.1046 - val_accuracy: 0.7774 - val_loss: 0.0934
# Epoch 40/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7317 - loss: 0.1035 - val_accuracy: 0.7888 - val_loss: 0.0929
# Epoch 41/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7252 - loss: 0.1012 - val_accuracy: 0.7911 - val_loss: 0.0889
# Epoch 42/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7325 - loss: 0.1026 - val_accuracy: 0.7735 - val_loss: 0.0930
# Epoch 43/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7183 - loss: 0.1040 - val_accuracy: 0.7854 - val_loss: 0.0894
# Epoch 44/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7323 - loss: 0.1027 - val_accuracy: 0.7754 - val_loss: 0.0932
# Epoch 45/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7243 - loss: 0.1043 - val_accuracy: 0.7835 - val_loss: 0.0913
# Epoch 46/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7345 - loss: 0.0996 - val_accuracy: 0.7781 - val_loss: 0.0919
# Epoch 47/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7396 - loss: 0.0965 - val_accuracy: 0.7663 - val_loss: 0.0913
# Epoch 48/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7320 - loss: 0.0998 - val_accuracy: 0.7800 - val_loss: 0.0942
# Epoch 49/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7387 - loss: 0.0993 - val_accuracy: 0.7869 - val_loss: 0.0900
# Epoch 50/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7389 - loss: 0.0973 - val_accuracy: 0.7838 - val_loss: 0.0906
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Fold 3: Using file /kaggle/input/GCN_minmax_baseline_version4/clean_week1/train/5-folds/data_part_3.csv as test set
# Epoch 1/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.6113 - loss: 0.1630 - val_accuracy: 0.6545 - val_loss: 0.1333
# Epoch 2/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6372 - loss: 0.1337 - val_accuracy: 0.5957 - val_loss: 0.1338
# Epoch 3/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6301 - loss: 0.1314 - val_accuracy: 0.6049 - val_loss: 0.1287
# Epoch 4/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6405 - loss: 0.1309 - val_accuracy: 0.6114 - val_loss: 0.1289
# Epoch 5/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6428 - loss: 0.1278 - val_accuracy: 0.5969 - val_loss: 0.1243
# Epoch 6/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6489 - loss: 0.1226 - val_accuracy: 0.6209 - val_loss: 0.1176
# Epoch 7/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6645 - loss: 0.1209 - val_accuracy: 0.6751 - val_loss: 0.1178
# Epoch 8/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6762 - loss: 0.1202 - val_accuracy: 0.6812 - val_loss: 0.1139
# Epoch 9/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6795 - loss: 0.1172 - val_accuracy: 0.6995 - val_loss: 0.1101
# Epoch 10/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6858 - loss: 0.1156 - val_accuracy: 0.7014 - val_loss: 0.1088
# Epoch 11/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6788 - loss: 0.1196 - val_accuracy: 0.6819 - val_loss: 0.1085
# Epoch 12/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6855 - loss: 0.1169 - val_accuracy: 0.6926 - val_loss: 0.1086
# Epoch 13/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6841 - loss: 0.1147 - val_accuracy: 0.7216 - val_loss: 0.1044
# Epoch 14/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6921 - loss: 0.1127 - val_accuracy: 0.7071 - val_loss: 0.1053
# Epoch 15/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6869 - loss: 0.1182 - val_accuracy: 0.7105 - val_loss: 0.1095
# Epoch 16/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6924 - loss: 0.1165 - val_accuracy: 0.7243 - val_loss: 0.1046
# Epoch 17/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7046 - loss: 0.1122 - val_accuracy: 0.7277 - val_loss: 0.1084
# Epoch 18/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6973 - loss: 0.1116 - val_accuracy: 0.7250 - val_loss: 0.1057
# Epoch 19/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6864 - loss: 0.1153 - val_accuracy: 0.7296 - val_loss: 0.1041
# Epoch 20/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7145 - loss: 0.1123 - val_accuracy: 0.7143 - val_loss: 0.1033
# Epoch 21/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7043 - loss: 0.1098 - val_accuracy: 0.7326 - val_loss: 0.1058
# Epoch 22/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7125 - loss: 0.1098 - val_accuracy: 0.7468 - val_loss: 0.1021
# Epoch 23/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7035 - loss: 0.1097 - val_accuracy: 0.7128 - val_loss: 0.1068
# Epoch 24/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7096 - loss: 0.1068 - val_accuracy: 0.7235 - val_loss: 0.1036
# Epoch 25/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7022 - loss: 0.1122 - val_accuracy: 0.7387 - val_loss: 0.1076
# Epoch 26/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7254 - loss: 0.1068 - val_accuracy: 0.7300 - val_loss: 0.1031
# Epoch 27/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7159 - loss: 0.1066 - val_accuracy: 0.7395 - val_loss: 0.0990
# Epoch 28/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7140 - loss: 0.1090 - val_accuracy: 0.7365 - val_loss: 0.1031
# Epoch 29/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7242 - loss: 0.1077 - val_accuracy: 0.7380 - val_loss: 0.1015
# Epoch 30/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7190 - loss: 0.1083 - val_accuracy: 0.7395 - val_loss: 0.1010
# Epoch 31/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7210 - loss: 0.1072 - val_accuracy: 0.7353 - val_loss: 0.1000
# Epoch 32/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7145 - loss: 0.1083 - val_accuracy: 0.7323 - val_loss: 0.0995
# Epoch 33/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7212 - loss: 0.1057 - val_accuracy: 0.7395 - val_loss: 0.1002
# Epoch 34/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7207 - loss: 0.1067 - val_accuracy: 0.7365 - val_loss: 0.1004
# Epoch 35/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7184 - loss: 0.1082 - val_accuracy: 0.7567 - val_loss: 0.1017
# Epoch 36/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7186 - loss: 0.1080 - val_accuracy: 0.7544 - val_loss: 0.0975
# Epoch 37/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7099 - loss: 0.1096 - val_accuracy: 0.7292 - val_loss: 0.1026
# Epoch 38/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7250 - loss: 0.1051 - val_accuracy: 0.7479 - val_loss: 0.0971
# Epoch 39/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7283 - loss: 0.1054 - val_accuracy: 0.7403 - val_loss: 0.1023
# Epoch 40/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7261 - loss: 0.1060 - val_accuracy: 0.7479 - val_loss: 0.1004
# Epoch 41/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7254 - loss: 0.1065 - val_accuracy: 0.7506 - val_loss: 0.0970
# Epoch 42/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7249 - loss: 0.1029 - val_accuracy: 0.7540 - val_loss: 0.0981
# Epoch 43/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7272 - loss: 0.1057 - val_accuracy: 0.6522 - val_loss: 0.1170
# Epoch 44/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6946 - loss: 0.1135 - val_accuracy: 0.7124 - val_loss: 0.1096
# Epoch 45/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7151 - loss: 0.1072 - val_accuracy: 0.7403 - val_loss: 0.1041
# Epoch 46/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7082 - loss: 0.1101 - val_accuracy: 0.7227 - val_loss: 0.1076
# Epoch 47/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7196 - loss: 0.1071 - val_accuracy: 0.7468 - val_loss: 0.0982
# Epoch 48/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7161 - loss: 0.1079 - val_accuracy: 0.7670 - val_loss: 0.1004
# Epoch 49/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7262 - loss: 0.1038 - val_accuracy: 0.7319 - val_loss: 0.1021
# Epoch 50/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7308 - loss: 0.1062 - val_accuracy: 0.7544 - val_loss: 0.1004
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Fold 4: Using file /kaggle/input/GCN_minmax_baseline_version4/clean_week1/train/5-folds/data_part_4.csv as test set
# Epoch 1/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.6060 - loss: 0.1662 - val_accuracy: 0.6854 - val_loss: 0.1273
# Epoch 2/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6256 - loss: 0.1333 - val_accuracy: 0.6281 - val_loss: 0.1243
# Epoch 3/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6318 - loss: 0.1294 - val_accuracy: 0.6964 - val_loss: 0.1163
# Epoch 4/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6517 - loss: 0.1235 - val_accuracy: 0.6926 - val_loss: 0.1103
# Epoch 5/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6610 - loss: 0.1223 - val_accuracy: 0.7033 - val_loss: 0.1095
# Epoch 6/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6608 - loss: 0.1210 - val_accuracy: 0.6960 - val_loss: 0.1098
# Epoch 7/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6642 - loss: 0.1204 - val_accuracy: 0.6960 - val_loss: 0.1102
# Epoch 8/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6554 - loss: 0.1211 - val_accuracy: 0.6869 - val_loss: 0.1153
# Epoch 9/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6646 - loss: 0.1191 - val_accuracy: 0.7117 - val_loss: 0.1029
# Epoch 10/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6853 - loss: 0.1148 - val_accuracy: 0.6304 - val_loss: 0.1203
# Epoch 11/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6870 - loss: 0.1139 - val_accuracy: 0.7250 - val_loss: 0.1009
# Epoch 12/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6790 - loss: 0.1158 - val_accuracy: 0.7330 - val_loss: 0.1009
# Epoch 13/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6798 - loss: 0.1155 - val_accuracy: 0.7433 - val_loss: 0.0970
# Epoch 14/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6938 - loss: 0.1130 - val_accuracy: 0.7399 - val_loss: 0.0992
# Epoch 15/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6983 - loss: 0.1117 - val_accuracy: 0.7277 - val_loss: 0.0963
# Epoch 16/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7030 - loss: 0.1092 - val_accuracy: 0.7300 - val_loss: 0.0997
# Epoch 17/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6950 - loss: 0.1121 - val_accuracy: 0.7437 - val_loss: 0.0966
# Epoch 18/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6987 - loss: 0.1116 - val_accuracy: 0.7555 - val_loss: 0.0985
# Epoch 19/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7102 - loss: 0.1083 - val_accuracy: 0.7449 - val_loss: 0.0959
# Epoch 20/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7067 - loss: 0.1078 - val_accuracy: 0.7597 - val_loss: 0.0948
# Epoch 21/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7093 - loss: 0.1088 - val_accuracy: 0.7479 - val_loss: 0.0992
# Epoch 22/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7147 - loss: 0.1065 - val_accuracy: 0.7582 - val_loss: 0.0965
# Epoch 23/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7241 - loss: 0.1046 - val_accuracy: 0.7635 - val_loss: 0.0978
# Epoch 24/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6969 - loss: 0.1105 - val_accuracy: 0.7281 - val_loss: 0.0953
# Epoch 25/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7031 - loss: 0.1120 - val_accuracy: 0.7624 - val_loss: 0.0939
# Epoch 26/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7045 - loss: 0.1105 - val_accuracy: 0.7693 - val_loss: 0.0965
# Epoch 27/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7119 - loss: 0.1076 - val_accuracy: 0.7670 - val_loss: 0.0932
# Epoch 28/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7267 - loss: 0.1047 - val_accuracy: 0.7666 - val_loss: 0.0898
# Epoch 29/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7208 - loss: 0.1038 - val_accuracy: 0.7475 - val_loss: 0.0941
# Epoch 30/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7140 - loss: 0.1073 - val_accuracy: 0.7494 - val_loss: 0.0973
# Epoch 31/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7176 - loss: 0.1052 - val_accuracy: 0.7437 - val_loss: 0.0959
# Epoch 32/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7254 - loss: 0.1038 - val_accuracy: 0.7548 - val_loss: 0.0968
# Epoch 33/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7137 - loss: 0.1059 - val_accuracy: 0.7544 - val_loss: 0.0928
# Epoch 34/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7347 - loss: 0.1029 - val_accuracy: 0.7750 - val_loss: 0.0888
# Epoch 35/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7271 - loss: 0.1041 - val_accuracy: 0.7696 - val_loss: 0.0907
# Epoch 36/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7231 - loss: 0.1052 - val_accuracy: 0.7586 - val_loss: 0.0936
# Epoch 37/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7389 - loss: 0.1012 - val_accuracy: 0.7750 - val_loss: 0.0912
# Epoch 38/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7347 - loss: 0.1006 - val_accuracy: 0.7685 - val_loss: 0.0921
# Epoch 39/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7221 - loss: 0.1005 - val_accuracy: 0.7773 - val_loss: 0.0854
# Epoch 40/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7379 - loss: 0.0993 - val_accuracy: 0.7864 - val_loss: 0.0861
# Epoch 41/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7295 - loss: 0.1018 - val_accuracy: 0.7670 - val_loss: 0.0937
# Epoch 42/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7291 - loss: 0.1015 - val_accuracy: 0.7670 - val_loss: 0.0910
# Epoch 43/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7432 - loss: 0.0991 - val_accuracy: 0.7681 - val_loss: 0.0907
# Epoch 44/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7328 - loss: 0.1016 - val_accuracy: 0.7872 - val_loss: 0.0842
# Epoch 45/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7281 - loss: 0.1013 - val_accuracy: 0.7788 - val_loss: 0.0869
# Epoch 46/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7361 - loss: 0.1011 - val_accuracy: 0.7784 - val_loss: 0.0851
# Epoch 47/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7320 - loss: 0.0992 - val_accuracy: 0.7838 - val_loss: 0.0843
# Epoch 48/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7417 - loss: 0.0974 - val_accuracy: 0.7830 - val_loss: 0.0834
# Epoch 49/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7308 - loss: 0.1015 - val_accuracy: 0.7780 - val_loss: 0.0885
# Epoch 50/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7269 - loss: 0.1040 - val_accuracy: 0.7727 - val_loss: 0.0897
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Fold 5: Using file /kaggle/input/GCN_minmax_baseline_version4/clean_week1/train/5-folds/data_part_5.csv as test set
# Epoch 1/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.6004 - loss: 0.1642 - val_accuracy: 0.6137 - val_loss: 0.1289
# Epoch 2/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6240 - loss: 0.1322 - val_accuracy: 0.6262 - val_loss: 0.1210
# Epoch 3/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6379 - loss: 0.1243 - val_accuracy: 0.6621 - val_loss: 0.1173
# Epoch 4/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6235 - loss: 0.1259 - val_accuracy: 0.6354 - val_loss: 0.1184
# Epoch 5/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6330 - loss: 0.1257 - val_accuracy: 0.6457 - val_loss: 0.1122
# Epoch 6/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6495 - loss: 0.1238 - val_accuracy: 0.6758 - val_loss: 0.1091
# Epoch 7/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6716 - loss: 0.1180 - val_accuracy: 0.6533 - val_loss: 0.1101
# Epoch 8/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6816 - loss: 0.1157 - val_accuracy: 0.6651 - val_loss: 0.1074
# Epoch 9/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6742 - loss: 0.1171 - val_accuracy: 0.7273 - val_loss: 0.1019
# Epoch 10/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6835 - loss: 0.1160 - val_accuracy: 0.6556 - val_loss: 0.1073
# Epoch 11/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6792 - loss: 0.1132 - val_accuracy: 0.7174 - val_loss: 0.1043
# Epoch 12/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6881 - loss: 0.1146 - val_accuracy: 0.7155 - val_loss: 0.1013
# Epoch 13/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6998 - loss: 0.1118 - val_accuracy: 0.7407 - val_loss: 0.0988
# Epoch 14/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6982 - loss: 0.1120 - val_accuracy: 0.7365 - val_loss: 0.0968
# Epoch 15/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7085 - loss: 0.1085 - val_accuracy: 0.7483 - val_loss: 0.0980
# Epoch 16/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6949 - loss: 0.1113 - val_accuracy: 0.7551 - val_loss: 0.0959
# Epoch 17/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7000 - loss: 0.1090 - val_accuracy: 0.6842 - val_loss: 0.1069
# Epoch 18/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7055 - loss: 0.1102 - val_accuracy: 0.7647 - val_loss: 0.0944
# Epoch 19/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7021 - loss: 0.1097 - val_accuracy: 0.7490 - val_loss: 0.0956
# Epoch 20/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7105 - loss: 0.1089 - val_accuracy: 0.7616 - val_loss: 0.0975
# Epoch 21/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7013 - loss: 0.1094 - val_accuracy: 0.7578 - val_loss: 0.0943
# Epoch 22/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7194 - loss: 0.1058 - val_accuracy: 0.7708 - val_loss: 0.0932
# Epoch 23/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7182 - loss: 0.1021 - val_accuracy: 0.7662 - val_loss: 0.0935
# Epoch 24/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7218 - loss: 0.1053 - val_accuracy: 0.7544 - val_loss: 0.0939
# Epoch 25/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7128 - loss: 0.1059 - val_accuracy: 0.7601 - val_loss: 0.0943
# Epoch 26/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7171 - loss: 0.1069 - val_accuracy: 0.7567 - val_loss: 0.0926
# Epoch 27/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7187 - loss: 0.1045 - val_accuracy: 0.7418 - val_loss: 0.0993
# Epoch 28/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7167 - loss: 0.1086 - val_accuracy: 0.7712 - val_loss: 0.0947
# Epoch 29/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7200 - loss: 0.1059 - val_accuracy: 0.7555 - val_loss: 0.0951
# Epoch 30/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7166 - loss: 0.1079 - val_accuracy: 0.7597 - val_loss: 0.0945
# Epoch 31/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7197 - loss: 0.1066 - val_accuracy: 0.7647 - val_loss: 0.0919
# Epoch 32/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7291 - loss: 0.1034 - val_accuracy: 0.7662 - val_loss: 0.0893
# Epoch 33/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7262 - loss: 0.1043 - val_accuracy: 0.7693 - val_loss: 0.0946
# Epoch 34/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7276 - loss: 0.1006 - val_accuracy: 0.7750 - val_loss: 0.0892
# Epoch 35/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7274 - loss: 0.1030 - val_accuracy: 0.7647 - val_loss: 0.0899
# Epoch 36/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7398 - loss: 0.1005 - val_accuracy: 0.7754 - val_loss: 0.0917
# Epoch 37/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7254 - loss: 0.1045 - val_accuracy: 0.7735 - val_loss: 0.0891
# Epoch 38/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7373 - loss: 0.1002 - val_accuracy: 0.7677 - val_loss: 0.0869
# Epoch 39/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7317 - loss: 0.1011 - val_accuracy: 0.7689 - val_loss: 0.0856
# Epoch 40/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7414 - loss: 0.0994 - val_accuracy: 0.7811 - val_loss: 0.0843
# Epoch 41/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7357 - loss: 0.1004 - val_accuracy: 0.7780 - val_loss: 0.0870
# Epoch 42/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7325 - loss: 0.1012 - val_accuracy: 0.7792 - val_loss: 0.0871
# Epoch 43/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7352 - loss: 0.1004 - val_accuracy: 0.7742 - val_loss: 0.0854
# Epoch 44/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7450 - loss: 0.0975 - val_accuracy: 0.7826 - val_loss: 0.0833
# Epoch 45/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7367 - loss: 0.1006 - val_accuracy: 0.7750 - val_loss: 0.0856
# Epoch 46/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7336 - loss: 0.1015 - val_accuracy: 0.7887 - val_loss: 0.0846
# Epoch 47/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7454 - loss: 0.0982 - val_accuracy: 0.7761 - val_loss: 0.0828
# Epoch 48/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7465 - loss: 0.0962 - val_accuracy: 0.7773 - val_loss: 0.0855
# Epoch 49/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7402 - loss: 0.0988 - val_accuracy: 0.7735 - val_loss: 0.0869
# Epoch 50/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7540 - loss: 0.0955 - val_accuracy: 0.7628 - val_loss: 0.0904
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
#
# === Average Accuracy ===
# 0.7705
#
# === Average Macro Metrics ===
# Macro Precision: 0.5658
# Macro Recall: 0.5268
# Macro F1-Score: 0.5354
# Macro AUC-ROC: 0.8682
#
# === Average Weighted Metrics ===
# Weighted Precision: 0.7454
# Weighted Recall: 0.7705
# Weighted F1-Score: 0.7547
# Weighted AUC-ROC: 0.8927
#
# === Average Metrics per Label ===
#    Label  Average Precision  Average Recall  Average F1-Score  Average AUC
# 0      0           0.664101        0.650333          0.656388     0.856706
# 1      1           0.137500        0.025000          0.042308     0.828631
# 2      2           0.539399        0.549897          0.541719     0.858736
# 3      3           0.647660        0.501796          0.564297     0.882926
# 4      4           0.840316        0.906817          0.872087     0.914220
#
# === Average Confusion Matrix ===
#        0    1     2     3       4
# 0  390.2  0.2  29.6  26.8   153.2
# 1   42.4  2.2   4.0   2.6    36.4
# 2   34.4  0.2  90.4   6.2    33.2
# 3   24.8  0.0   4.4  83.8    54.0
# 4   97.8  0.6  40.8  10.2  1454.0
#
# Processing week2 with best parameters...
# best parameters for week2: {'units_1': 160, 'dropout_1': 0.2, 'units_2': 160, 'dropout_2': 0.5, 'units_3': 96, 'dropout_3': 0.5, 'units_4': 192, 'dropout_4': 0.1, 'learning_rate': 0.0014789571342550213}
# Fold 1: Using file /kaggle/input/GCN_minmax_baseline_version4/clean_week2/train/5-folds/data_part_1.csv as test set
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.6129 - loss: 0.1521 - val_accuracy: 0.6752 - val_loss: 0.1128
# Epoch 2/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6829 - loss: 0.1162 - val_accuracy: 0.7251 - val_loss: 0.1053
# Epoch 3/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7074 - loss: 0.1097 - val_accuracy: 0.7678 - val_loss: 0.0967
# Epoch 4/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7259 - loss: 0.1048 - val_accuracy: 0.7476 - val_loss: 0.0941
# Epoch 5/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7507 - loss: 0.0994 - val_accuracy: 0.8189 - val_loss: 0.0784
# Epoch 6/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7731 - loss: 0.0923 - val_accuracy: 0.7899 - val_loss: 0.0825
# Epoch 7/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7631 - loss: 0.0927 - val_accuracy: 0.8250 - val_loss: 0.0734
# Epoch 8/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7941 - loss: 0.0851 - val_accuracy: 0.8242 - val_loss: 0.0737
# Epoch 9/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8054 - loss: 0.0806 - val_accuracy: 0.8059 - val_loss: 0.0768
# Epoch 10/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8020 - loss: 0.0810 - val_accuracy: 0.8193 - val_loss: 0.0726
# Epoch 11/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7984 - loss: 0.0811 - val_accuracy: 0.8250 - val_loss: 0.0728
# Epoch 12/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8116 - loss: 0.0794 - val_accuracy: 0.8262 - val_loss: 0.0713
# Epoch 13/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8097 - loss: 0.0766 - val_accuracy: 0.8239 - val_loss: 0.0715
# Epoch 14/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8250 - loss: 0.0748 - val_accuracy: 0.8441 - val_loss: 0.0631
# Epoch 15/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8135 - loss: 0.0764 - val_accuracy: 0.8395 - val_loss: 0.0651
# Epoch 16/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8073 - loss: 0.0774 - val_accuracy: 0.8220 - val_loss: 0.0741
# Epoch 17/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8056 - loss: 0.0789 - val_accuracy: 0.8368 - val_loss: 0.0660
# Epoch 18/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8085 - loss: 0.0758 - val_accuracy: 0.8456 - val_loss: 0.0618
# Epoch 19/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8219 - loss: 0.0720 - val_accuracy: 0.8418 - val_loss: 0.0669
# Epoch 20/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8223 - loss: 0.0729 - val_accuracy: 0.7888 - val_loss: 0.0842
# Epoch 21/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8166 - loss: 0.0732 - val_accuracy: 0.8502 - val_loss: 0.0624
# Epoch 22/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8231 - loss: 0.0716 - val_accuracy: 0.8528 - val_loss: 0.0609
# Epoch 23/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8206 - loss: 0.0727 - val_accuracy: 0.8357 - val_loss: 0.0661
# Epoch 24/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8230 - loss: 0.0717 - val_accuracy: 0.8262 - val_loss: 0.0665
# Epoch 25/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8306 - loss: 0.0688 - val_accuracy: 0.8323 - val_loss: 0.0692
# Epoch 26/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8260 - loss: 0.0696 - val_accuracy: 0.8502 - val_loss: 0.0594
# Epoch 27/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8299 - loss: 0.0688 - val_accuracy: 0.8486 - val_loss: 0.0598
# Epoch 28/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8219 - loss: 0.0701 - val_accuracy: 0.8460 - val_loss: 0.0615
# Epoch 29/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8288 - loss: 0.0689 - val_accuracy: 0.8582 - val_loss: 0.0556
# Epoch 30/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8275 - loss: 0.0657 - val_accuracy: 0.8258 - val_loss: 0.0726
# Epoch 31/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8171 - loss: 0.0724 - val_accuracy: 0.8559 - val_loss: 0.0561
# Epoch 32/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8269 - loss: 0.0678 - val_accuracy: 0.8608 - val_loss: 0.0564
# Epoch 33/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8331 - loss: 0.0638 - val_accuracy: 0.8643 - val_loss: 0.0564
# Epoch 34/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8340 - loss: 0.0658 - val_accuracy: 0.8578 - val_loss: 0.0580
# Epoch 35/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8373 - loss: 0.0643 - val_accuracy: 0.8578 - val_loss: 0.0569
# Epoch 36/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8368 - loss: 0.0635 - val_accuracy: 0.8662 - val_loss: 0.0554
# Epoch 37/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8361 - loss: 0.0643 - val_accuracy: 0.8536 - val_loss: 0.0563
# Epoch 38/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8325 - loss: 0.0628 - val_accuracy: 0.8269 - val_loss: 0.0638
# Epoch 39/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8393 - loss: 0.0647 - val_accuracy: 0.8620 - val_loss: 0.0602
# Epoch 40/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8352 - loss: 0.0661 - val_accuracy: 0.8723 - val_loss: 0.0521
# Epoch 41/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8364 - loss: 0.0620 - val_accuracy: 0.8650 - val_loss: 0.0532
# Epoch 42/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8290 - loss: 0.0675 - val_accuracy: 0.8715 - val_loss: 0.0505
# Epoch 43/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8382 - loss: 0.0641 - val_accuracy: 0.8715 - val_loss: 0.0510
# Epoch 44/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8368 - loss: 0.0626 - val_accuracy: 0.8669 - val_loss: 0.0526
# Epoch 45/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8480 - loss: 0.0612 - val_accuracy: 0.8689 - val_loss: 0.0530
# Epoch 46/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8455 - loss: 0.0585 - val_accuracy: 0.8692 - val_loss: 0.0520
# Epoch 47/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8464 - loss: 0.0600 - val_accuracy: 0.8700 - val_loss: 0.0488
# Epoch 48/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8481 - loss: 0.0605 - val_accuracy: 0.8822 - val_loss: 0.0476
# Epoch 49/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8400 - loss: 0.0608 - val_accuracy: 0.8742 - val_loss: 0.0479
# Epoch 50/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8426 - loss: 0.0596 - val_accuracy: 0.8868 - val_loss: 0.0463
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Fold 2: Using file /kaggle/input/GCN_minmax_baseline_version4/clean_week2/train/5-folds/data_part_2.csv as test set
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.5987 - loss: 0.1534 - val_accuracy: 0.6828 - val_loss: 0.1152
# Epoch 2/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6511 - loss: 0.1191 - val_accuracy: 0.7396 - val_loss: 0.1059
# Epoch 3/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6886 - loss: 0.1107 - val_accuracy: 0.7221 - val_loss: 0.1121
# Epoch 4/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6971 - loss: 0.1088 - val_accuracy: 0.7510 - val_loss: 0.0998
# Epoch 5/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7373 - loss: 0.0998 - val_accuracy: 0.7602 - val_loss: 0.0965
# Epoch 6/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7344 - loss: 0.1020 - val_accuracy: 0.7735 - val_loss: 0.0914
# Epoch 7/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7467 - loss: 0.0999 - val_accuracy: 0.8021 - val_loss: 0.0855
# Epoch 8/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7506 - loss: 0.0953 - val_accuracy: 0.7995 - val_loss: 0.0840
# Epoch 9/50
# ...
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Fold 4: Using file /kaggle/input/GCN_minmax_baseline_version4/clean_week4/train/5-folds/data_part_4.csv as test set
# Epoch 1/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.6012 - loss: 0.1471 - val_accuracy: 0.6323 - val_loss: 0.1236
# Epoch 2/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6507 - loss: 0.1224 - val_accuracy: 0.6609 - val_loss: 0.1237
# Epoch 3/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6757 - loss: 0.1235 - val_accuracy: 0.6846 - val_loss: 0.1129
# Epoch 4/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7052 - loss: 0.1155 - val_accuracy: 0.7796 - val_loss: 0.0909
# Epoch 5/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7448 - loss: 0.1019 - val_accuracy: 0.8291 - val_loss: 0.0793
# Epoch 6/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7373 - loss: 0.1066 - val_accuracy: 0.8299 - val_loss: 0.0760
# Epoch 7/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7619 - loss: 0.0989 - val_accuracy: 0.8284 - val_loss: 0.0772
# Epoch 8/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7991 - loss: 0.0887 - val_accuracy: 0.8333 - val_loss: 0.0745
# Epoch 9/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7646 - loss: 0.0961 - val_accuracy: 0.8139 - val_loss: 0.0862
# Epoch 10/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7716 - loss: 0.0958 - val_accuracy: 0.8074 - val_loss: 0.0825
# Epoch 11/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7669 - loss: 0.0970 - val_accuracy: 0.8089 - val_loss: 0.0893
# Epoch 12/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7232 - loss: 0.1059 - val_accuracy: 0.7510 - val_loss: 0.0990
# Epoch 13/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7878 - loss: 0.0893 - val_accuracy: 0.8402 - val_loss: 0.0684
# Epoch 14/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7901 - loss: 0.0867 - val_accuracy: 0.8337 - val_loss: 0.0704
# Epoch 15/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7928 - loss: 0.0869 - val_accuracy: 0.8490 - val_loss: 0.0615
# Epoch 16/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8159 - loss: 0.0800 - val_accuracy: 0.8272 - val_loss: 0.0739
# Epoch 17/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8061 - loss: 0.0838 - val_accuracy: 0.7990 - val_loss: 0.0889
# Epoch 18/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8162 - loss: 0.0772 - val_accuracy: 0.8154 - val_loss: 0.0767
# Epoch 19/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7747 - loss: 0.0927 - val_accuracy: 0.8619 - val_loss: 0.0630
# Epoch 20/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7641 - loss: 0.0929 - val_accuracy: 0.8337 - val_loss: 0.0723
# Epoch 21/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7871 - loss: 0.0894 - val_accuracy: 0.8223 - val_loss: 0.0789
# Epoch 22/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7570 - loss: 0.0957 - val_accuracy: 0.8585 - val_loss: 0.0665
# Epoch 23/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8006 - loss: 0.0842 - val_accuracy: 0.8543 - val_loss: 0.0618
# Epoch 24/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8018 - loss: 0.0824 - val_accuracy: 0.8692 - val_loss: 0.0591
# Epoch 25/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8242 - loss: 0.0758 - val_accuracy: 0.8463 - val_loss: 0.0608
# Epoch 26/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8095 - loss: 0.0788 - val_accuracy: 0.8440 - val_loss: 0.0719
# Epoch 27/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8098 - loss: 0.0807 - val_accuracy: 0.8562 - val_loss: 0.0633
# Epoch 28/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8060 - loss: 0.0803 - val_accuracy: 0.8509 - val_loss: 0.0650
# Epoch 29/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7824 - loss: 0.0888 - val_accuracy: 0.8574 - val_loss: 0.0636
# Epoch 30/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8124 - loss: 0.0800 - val_accuracy: 0.8658 - val_loss: 0.0561
# Epoch 31/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8269 - loss: 0.0733 - val_accuracy: 0.8707 - val_loss: 0.0569
# Epoch 32/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8354 - loss: 0.0727 - val_accuracy: 0.8665 - val_loss: 0.0573
# Epoch 33/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8457 - loss: 0.0679 - val_accuracy: 0.8463 - val_loss: 0.0588
# Epoch 34/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7836 - loss: 0.0831 - val_accuracy: 0.7086 - val_loss: 0.0992
# Epoch 35/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7792 - loss: 0.0909 - val_accuracy: 0.7540 - val_loss: 0.0942
# Epoch 36/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7930 - loss: 0.0861 - val_accuracy: 0.8604 - val_loss: 0.0580
# Epoch 37/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8265 - loss: 0.0735 - val_accuracy: 0.8532 - val_loss: 0.0635
# Epoch 38/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8011 - loss: 0.0839 - val_accuracy: 0.8455 - val_loss: 0.0728
# Epoch 39/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8020 - loss: 0.0837 - val_accuracy: 0.8471 - val_loss: 0.0566
# Epoch 40/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8222 - loss: 0.0725 - val_accuracy: 0.8616 - val_loss: 0.0587
# Epoch 41/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8272 - loss: 0.0706 - val_accuracy: 0.8417 - val_loss: 0.0752
# Epoch 42/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8067 - loss: 0.0833 - val_accuracy: 0.8436 - val_loss: 0.0610
# Epoch 43/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8000 - loss: 0.0812 - val_accuracy: 0.8574 - val_loss: 0.0704
# Epoch 44/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7936 - loss: 0.0837 - val_accuracy: 0.8574 - val_loss: 0.0587
# Epoch 45/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8310 - loss: 0.0708 - val_accuracy: 0.8169 - val_loss: 0.0810
# Epoch 46/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8111 - loss: 0.0778 - val_accuracy: 0.8650 - val_loss: 0.0559
# Epoch 47/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8155 - loss: 0.0770 - val_accuracy: 0.8524 - val_loss: 0.0664
# Epoch 48/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8184 - loss: 0.0770 - val_accuracy: 0.8623 - val_loss: 0.0537
# Epoch 49/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8051 - loss: 0.0779 - val_accuracy: 0.8509 - val_loss: 0.0599
# Epoch 50/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8306 - loss: 0.0691 - val_accuracy: 0.7704 - val_loss: 0.0913
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Fold 5: Using file /kaggle/input/GCN_minmax_baseline_version4/clean_week4/train/5-folds/data_part_5.csv as test set
# Epoch 1/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.6018 - loss: 0.1486 - val_accuracy: 0.6346 - val_loss: 0.1161
# Epoch 2/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6820 - loss: 0.1197 - val_accuracy: 0.7746 - val_loss: 0.0989
# Epoch 3/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7365 - loss: 0.1091 - val_accuracy: 0.7727 - val_loss: 0.0964
# Epoch 4/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7045 - loss: 0.1139 - val_accuracy: 0.6751 - val_loss: 0.1153
# Epoch 5/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6570 - loss: 0.1237 - val_accuracy: 0.8322 - val_loss: 0.0776
# Epoch 6/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7220 - loss: 0.1099 - val_accuracy: 0.7818 - val_loss: 0.0926
# Epoch 7/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7412 - loss: 0.1069 - val_accuracy: 0.6541 - val_loss: 0.1179
# Epoch 8/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6493 - loss: 0.1253 - val_accuracy: 0.6400 - val_loss: 0.1175
# Epoch 9/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6613 - loss: 0.1208 - val_accuracy: 0.6861 - val_loss: 0.1058
# Epoch 10/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7382 - loss: 0.1051 - val_accuracy: 0.7307 - val_loss: 0.1104
# Epoch 11/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7001 - loss: 0.1181 - val_accuracy: 0.6465 - val_loss: 0.1141
# Epoch 12/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7106 - loss: 0.1082 - val_accuracy: 0.7269 - val_loss: 0.1039
# Epoch 13/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7270 - loss: 0.1062 - val_accuracy: 0.8417 - val_loss: 0.0694
# Epoch 14/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7583 - loss: 0.0978 - val_accuracy: 0.8394 - val_loss: 0.0703
# Epoch 15/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8070 - loss: 0.0847 - val_accuracy: 0.7201 - val_loss: 0.1015
# Epoch 16/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7323 - loss: 0.1020 - val_accuracy: 0.8314 - val_loss: 0.0719
# Epoch 17/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7871 - loss: 0.0918 - val_accuracy: 0.7143 - val_loss: 0.1038
# Epoch 18/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7316 - loss: 0.1043 - val_accuracy: 0.8120 - val_loss: 0.0798
# Epoch 19/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7897 - loss: 0.0903 - val_accuracy: 0.8440 - val_loss: 0.0689
# Epoch 20/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8088 - loss: 0.0847 - val_accuracy: 0.8467 - val_loss: 0.0684
# Epoch 21/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8054 - loss: 0.0837 - val_accuracy: 0.6743 - val_loss: 0.1236
# Epoch 22/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7428 - loss: 0.1012 - val_accuracy: 0.8337 - val_loss: 0.0717
# Epoch 23/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8163 - loss: 0.0804 - val_accuracy: 0.8444 - val_loss: 0.0710
# Epoch 24/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8025 - loss: 0.0837 - val_accuracy: 0.8436 - val_loss: 0.0697
# Epoch 25/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8040 - loss: 0.0814 - val_accuracy: 0.7311 - val_loss: 0.0993
# Epoch 26/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8057 - loss: 0.0812 - val_accuracy: 0.8619 - val_loss: 0.0623
# Epoch 27/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8175 - loss: 0.0777 - val_accuracy: 0.8547 - val_loss: 0.0619
# Epoch 28/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8232 - loss: 0.0769 - val_accuracy: 0.8596 - val_loss: 0.0539
# Epoch 29/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8307 - loss: 0.0726 - val_accuracy: 0.7201 - val_loss: 0.1039
# Epoch 30/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7798 - loss: 0.0893 - val_accuracy: 0.8188 - val_loss: 0.0822
# Epoch 31/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7802 - loss: 0.0915 - val_accuracy: 0.6911 - val_loss: 0.1146
# Epoch 32/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7837 - loss: 0.0892 - val_accuracy: 0.8635 - val_loss: 0.0574
# Epoch 33/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8264 - loss: 0.0767 - val_accuracy: 0.8654 - val_loss: 0.0566
# Epoch 34/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8297 - loss: 0.0736 - val_accuracy: 0.8444 - val_loss: 0.0685
# Epoch 35/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8269 - loss: 0.0732 - val_accuracy: 0.8555 - val_loss: 0.0598
# Epoch 36/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7904 - loss: 0.0874 - val_accuracy: 0.8345 - val_loss: 0.0643
# Epoch 37/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8173 - loss: 0.0748 - val_accuracy: 0.7952 - val_loss: 0.0741
# Epoch 38/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8004 - loss: 0.0837 - val_accuracy: 0.8196 - val_loss: 0.0776
# Epoch 39/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8281 - loss: 0.0733 - val_accuracy: 0.8616 - val_loss: 0.0551
# Epoch 40/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8287 - loss: 0.0702 - val_accuracy: 0.8661 - val_loss: 0.0531
# Epoch 41/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8317 - loss: 0.0694 - val_accuracy: 0.8352 - val_loss: 0.0614
# Epoch 42/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8160 - loss: 0.0762 - val_accuracy: 0.8703 - val_loss: 0.0532
# Epoch 43/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8357 - loss: 0.0690 - val_accuracy: 0.8734 - val_loss: 0.0520
# Epoch 44/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8251 - loss: 0.0741 - val_accuracy: 0.8543 - val_loss: 0.0590
# Epoch 45/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8160 - loss: 0.0731 - val_accuracy: 0.8452 - val_loss: 0.0675
# Epoch 46/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8328 - loss: 0.0713 - val_accuracy: 0.8654 - val_loss: 0.0550
# Epoch 47/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8357 - loss: 0.0684 - val_accuracy: 0.8452 - val_loss: 0.0616
# Epoch 48/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8226 - loss: 0.0735 - val_accuracy: 0.8707 - val_loss: 0.0536
# Epoch 49/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8261 - loss: 0.0714 - val_accuracy: 0.8650 - val_loss: 0.0530
# Epoch 50/50
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8338 - loss: 0.0676 - val_accuracy: 0.8505 - val_loss: 0.0515
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
#
# === Average Accuracy ===
# 0.8236
#
# === Average Macro Metrics ===
# Macro Precision: 0.5663
# Macro Recall: 0.5285
# Macro F1-Score: 0.5301
# Macro AUC-ROC: 0.9096
#
# === Average Weighted Metrics ===
# Weighted Precision: 0.8025
# Weighted Recall: 0.8236
# Weighted F1-Score: 0.8017
# Weighted AUC-ROC: 0.9582
#
# === Average Metrics per Label ===
#    Label  Average Precision  Average Recall  Average F1-Score  Average AUC
# 0      0           0.672425        0.787667          0.707736     0.930995
# 1      1           0.000000        0.000000          0.000000     0.812909
# 2      2           0.714472        0.491463          0.578848     0.906278
# 3      3           0.509897        0.403593          0.420802     0.911263
# 4      4           0.934514        0.959830          0.943233     0.986540
#
# === Average Confusion Matrix ===
#        0    1     2     3       4
# 0  472.6  0.0  23.2  35.2    69.0
# 1   62.2  0.0   3.2   5.0    17.2
# 2   54.0  0.0  80.8   8.6    21.0
# 3   77.4  0.2   3.4  67.4    18.6
# 4   58.2  0.0   3.0   3.2  1539.0

# %%
# Duyệt qua các tuần trong overall_results
for week_result in overall_results_5folds:
    week = week_result["week"]
    average_train_time = np.mean(week_result["train_times"])
    average_test_time = np.mean(week_result["test_times"])
    average_metrics_df = week_result["average_metrics_df"]
    average_accuracy = np.mean(week_results["accuracy_per_fold"])
    average_confusion_matrix = week_result["average_confusion_matrix"]
    
    # In kết quả
    print(f"\n=== Results for {week} ===")
    print(f"Average Accurancy: {average_accuracy}")
    print(f"Average Train Time: {average_train_time:.4f} seconds")
    print(f"Average Test Time: {average_test_time:.4f} seconds")
    print(f"Average AUC Macro: {average_auc_macro}")
    print(f"Average AUC Weighted: {average_auc_weighted}")
    print("\nAverage Precision, Recall, F1-Score, AUC-ROC per Label:")
    print(average_metrics_df)
    print("\nAverage Confusion Matrix:")
    print(average_confusion_matrix)
# Out:
# === Results for week1 ===
# Average Accurancy: 0.8235916137695313
# Average Train Time: 137.9115 seconds
# Average Test Time: 0.7923 seconds
# Average AUC Macro: 0.9095970693120643
# Average AUC Weighted: 0.9582081303486953
#
# Average Precision, Recall, F1-Score, AUC-ROC per Label:
#    Label  Average Precision  Average Recall  Average F1-Score  Average AUC
# 0      0           0.664101        0.650333          0.656388     0.856706
# 1      1           0.137500        0.025000          0.042308     0.828631
# 2      2           0.539399        0.549897          0.541719     0.858736
# 3      3           0.647660        0.501796          0.564297     0.882926
# 4      4           0.840316        0.906817          0.872087     0.914220
#
# Average Confusion Matrix:
#        0    1     2     3       4
# 0  390.2  0.2  29.6  26.8   153.2
# 1   42.4  2.2   4.0   2.6    36.4
# 2   34.4  0.2  90.4   6.2    33.2
# 3   24.8  0.0   4.4  83.8    54.0
# 4   97.8  0.6  40.8  10.2  1454.0
#
# === Results for week2 ===
# Average Accurancy: 0.8235916137695313
# Average Train Time: 138.3593 seconds
# Average Test Time: 0.7796 seconds
# Average AUC Macro: 0.9095970693120643
# Average AUC Weighted: 0.9582081303486953
#
# Average Precision, Recall, F1-Score, AUC-ROC per Label:
#    Label  Average Precision  Average Recall  Average F1-Score  Average AUC
# 0      0           0.816174        0.789333          0.800062     0.965093
# 1      1           0.789459        0.630225          0.682244     0.971475
# 2      2           0.796748        0.526785          0.631880     0.924659
# 3      3           0.732014        0.692216          0.710803     0.954473
# 4      4           0.921623        0.975804          0.947553     0.988349
#
# Average Confusion Matrix:
#        0     1     2      3       4
# 0  473.6   3.6  11.8   12.8    98.2
# 1   17.8  55.2   3.8    9.0     1.8
# 2   47.4   3.2  86.6   11.2    16.0
# 3   21.0   8.0   3.4  115.6    19.0
# 4   22.8   2.4   3.6   10.0  1564.6
#
# === Results for week3 ===
# Average Accurancy: 0.8235916137695313
# Average Train Time: 139.2723 seconds
# Average Test Time: 0.7844 seconds
# Average AUC Macro: 0.9095970693120643
# Average AUC Weighted: 0.9582081303486953
#
# Average Precision, Recall, F1-Score, AUC-ROC per Label:
#    Label  Average Precision  Average Recall  Average F1-Score  Average AUC
# 0      0           0.750310        0.815667          0.781381     0.951735
# 1      1           0.516667        0.113689          0.139785     0.892117
# 2      2           0.686391        0.528004          0.595928     0.907089
# 3      3           0.587419        0.644311          0.612761     0.925151
# 4      4           0.943732        0.965324          0.954264     0.982578
#
# Average Confusion Matrix:
#        0     1     2      3       4
# 0  489.4   1.0  25.6   36.8    47.2
# 1   48.8  10.0   4.0   10.2    14.6
# 2   45.2   1.0  86.8   16.0    15.4
# 3   37.6   2.8   3.4  107.6    15.6
# 4   32.4   2.4   6.6   14.2  1547.8
#
# === Results for week4 ===
# Average Accurancy: 0.8235916137695313
# Average Train Time: 142.2789 seconds
# Average Test Time: 0.8065 seconds
# Average AUC Macro: 0.9095970693120643
# Average AUC Weighted: 0.9582081303486953
#
# Average Precision, Recall, F1-Score, AUC-ROC per Label:
#    Label  Average Precision  Average Recall  Average F1-Score  Average AUC
# 0      0           0.672425        0.787667          0.707736     0.930995
# 1      1           0.000000        0.000000          0.000000     0.812909
# 2      2           0.714472        0.491463          0.578848     0.906278
# 3      3           0.509897        0.403593          0.420802     0.911263
# 4      4           0.934514        0.959830          0.943233     0.986540
#
# Average Confusion Matrix:
#        0    1     2     3       4
# 0  472.6  0.0  23.2  35.2    69.0
# 1   62.2  0.0   3.2   5.0    17.2
# 2   54.0  0.0  80.8   8.6    21.0
# 3   77.4  0.2   3.4  67.4    18.6
# 4   58.2  0.0   3.0   3.2  1539.0

# %% [markdown]
# ## Kiểm tra trên tập test

# %%
from tensorflow.keras import layers
import tensorflow as tf
from tensorflow.keras import backend as K

# Định nghĩa Focal Loss
def focal_loss(gamma=2., alpha=0.25):
    def focal_loss_fixed(y_true, y_pred):
        y_pred = K.clip(y_pred, K.epsilon(), 1. - K.epsilon())
        cross_entropy = -y_true * K.log(y_pred)
        loss = alpha * K.pow(1 - y_pred, gamma) * cross_entropy
        return K.sum(loss, axis=-1)
    
    return focal_loss_fixed

def build_lstm_model(params):
    model = tf.keras.Sequential()
    
    # LSTM layer 1
    model.add(layers.LSTM(
        units=params.get('units_1', 32),
        return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2]))
    )
    model.add(layers.Dropout(rate=params.get('dropout_1', 0.2)))

    # LSTM layer 2
    model.add(layers.LSTM(
        units=params.get('units_2', 32),
        return_sequences=True
    ))
    model.add(layers.Dropout(rate=params.get('dropout_2', 0.2)))

    # LSTM layer 3
    model.add(layers.LSTM(
        units=params.get('units_3', 32),
        return_sequences=True
    ))
    model.add(layers.Dropout(rate=params.get('dropout_3', 0.2)))

    # LSTM layer 4
    model.add(layers.LSTM(
        units=params.get('units_4', 32),
        return_sequences=False
    ))
    model.add(layers.Dropout(rate=params.get('dropout_4', 0.2)))

    # Output layer
    model.add(layers.Dense(5, activation='softmax'))  # 5 classes in output

    # Compile the model
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=params['learning_rate']),
        loss=focal_loss(gamma=params.get('gamma', 2.), alpha=params.get('alpha', 0.25)),
        metrics=['accuracy']
    )
    
    return model

# %%
# Mảng lưu dữ liệu của các tuần
results = []

def process_week(week_num, best_params, results):
    print(f"\n=== Processing Week {week_num} ===")
    params = best_params[f"week{week_num}"].values
    # Đường dẫn tới dữ liệu tuần tương ứng
    train_path = f"{BASE_PATH}/clean_week{week_num}/train/clean_data_week{week_num}.csv"
    test_path = f"{BASE_PATH}/clean_week{week_num}/test/test_week{week_num}.csv"
    
    # Load dữ liệu
    train_data = pd.read_csv(train_path)
    test_data = pd.read_csv(test_path)
    
    # Tách X và y
    X_train = train_data.drop(columns=["classification_encoded", "user_id",
                                       "course_id", "school", "enroll_time", "classification"])
    y_train = train_data['classification_encoded']
    
    X_test = test_data.drop(columns=["classification_encoded", "user_id",
                                     "course_id", "school", "enroll_time", "classification"])
    y_test = test_data['classification_encoded']

    # Áp dụng SMOTE cho tập huấn luyện
    smote = SMOTE(random_state=42)
    X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

    # Chuyển đổi nhãn sang dạng one-hot
    y_train_resampled = to_categorical(y_train_resampled, num_classes=5)
    y_test = to_categorical(y_test, num_classes=5)

    # Reshape dữ liệu cho LSTM
    X_train_resampled = X_train_resampled.to_numpy().reshape((X_train_resampled.shape[0], 1, X_train_resampled.shape[1]))
    X_test = X_test.to_numpy().reshape((X_test.shape[0], 1, X_test.shape[1]))

    # Xây dựng mô hình với tham số tốt nhất
    model = build_lstm_model(params)
    
    # Huấn luyện mô hình
    start_train = time.time()
    model.fit(X_train_resampled, y_train_resampled, epochs=50, validation_split=0.1, batch_size=32)
    end_train = time.time()
    
    # Kiểm thử mô hình
    start_test = time.time()
    y_pred = model.predict(X_test)
    end_test = time.time()
    
    # Tính thời gian huấn luyện và kiểm thử
    train_time = end_train - start_train
    test_time = end_test - start_test
    
    # Đánh giá mô hình
    y_pred_classes = y_pred.argmax(axis=1)
    y_test_classes = y_test.argmax(axis=1)
    
    precision, recall, f1, _ = precision_recall_fscore_support(y_test_classes, y_pred_classes, average=None)
    precision_macro, recall_macro, f1_macro, _ = precision_recall_fscore_support(y_test_classes, y_pred_classes, average='macro')
    precision_weighted, recall_weighted, f1_weighted, _ = precision_recall_fscore_support(y_test_classes, y_pred_classes, average='weighted')
    conf_matrix = confusion_matrix(y_test_classes, y_pred_classes)
    accuracy = accuracy_score(y_test_classes, y_pred_classes)
    
    # Tính AUC-ROC (với one-vs-rest)
    try:
        auc_macro = roc_auc_score(y_test, y_pred, multi_class="ovr", average="macro")
        auc_per_class = roc_auc_score(y_test, y_pred, multi_class="ovr", average=None)
        # Tính AUC weighted tự tính theo trọng số mẫu của từng lớp
        supports = np.bincount(y_test_classes, minlength=5)
        auc_weighted = np.sum(auc_per_class * supports) / np.sum(supports)
    except Exception as e:
        print(f"Lỗi khi tính AUC: {e}")
        auc_macro = np.nan
        auc_per_class = [np.nan] * 5
        auc_weighted = np.nan

    # Lưu kết quả vào mảng
    results.append({
        "week": week_num,
        "train_time": train_time,
        "test_time": test_time,
        "precision": precision,
        "recall": recall,
        "f1_score": f1,
        "accuracy": accuracy,
        "precision_macro": precision_macro,
        "recall_macro": recall_macro,
        "f1_macro": f1_macro,
        "precision_weighted": precision_weighted,
        "recall_weighted": recall_weighted,
        "f1_weighted": f1_weighted,
        "auc_macro": auc_macro,
        "auc_weighted": auc_weighted,
        "auc_per_class": auc_per_class,
        "confusion_matrix": conf_matrix
    })
    
    # In kết quả chi tiết
    print("\n=== Precision, Recall, F1-Score per Label ===")
    print(pd.DataFrame({
        "Label": np.unique(y_test_classes),
        "Precision": precision,
        "Recall": recall,
        "F1-Score": f1
    }))

    print("\n=== Macro Averages & Accuracy ===")
    print(f"Macro Precision: {precision_macro:.4f}")
    print(f"Macro Recall: {recall_macro:.4f}")
    print(f"Macro F1-Score: {f1_macro:.4f}")
    print(f"Accuracy: {accuracy:.4f}")
    
    print("\n=== Weighted Averages ===")
    print(f"Weighted Precision: {precision_weighted:.4f}")
    print(f"Weighted Recall: {recall_weighted:.4f}")
    print(f"Weighted F1-Score: {f1_weighted:.4f}")
    
    print("\n=== AUC-ROC ===")
    print(f"AUC Macro: {auc_macro:.4f}")
    print(f"AUC Weighted: {auc_weighted:.4f}")
    print(f"AUC per Label: {auc_per_class}")
    
    print("\n=== Confusion Matrix ===")
    print(pd.DataFrame(conf_matrix, index=np.unique(y_test_classes), columns=np.unique(y_test_classes)))
    
    print(f"\nTrain Time: {train_time:.2f} seconds")
    print(f"Test Time: {test_time:.2f} seconds")

# %%
process_week(1, best_params, results)
# Out:
# === Processing Week 1 ===
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.3510 - loss: 0.2237 - val_accuracy: 0.5682 - val_loss: 0.2673
# Epoch 2/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.4924 - loss: 0.1921 - val_accuracy: 0.7129 - val_loss: 0.2017
# Epoch 3/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.5160 - loss: 0.1829 - val_accuracy: 0.7289 - val_loss: 0.2372
# Epoch 4/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.5425 - loss: 0.1775 - val_accuracy: 0.7166 - val_loss: 0.2325
# Epoch 5/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.5534 - loss: 0.1742 - val_accuracy: 0.7077 - val_loss: 0.2373
# Epoch 6/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.5714 - loss: 0.1688 - val_accuracy: 0.6416 - val_loss: 0.2627
# Epoch 7/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.5857 - loss: 0.1654 - val_accuracy: 0.6129 - val_loss: 0.2699
# Epoch 8/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.5865 - loss: 0.1655 - val_accuracy: 0.7171 - val_loss: 0.2289
# Epoch 9/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.5933 - loss: 0.1621 - val_accuracy: 0.7236 - val_loss: 0.2295
# Epoch 10/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.5917 - loss: 0.1626 - val_accuracy: 0.7111 - val_loss: 0.2416
# Epoch 11/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.5951 - loss: 0.1612 - val_accuracy: 0.7284 - val_loss: 0.2468
# Epoch 12/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.5905 - loss: 0.1619 - val_accuracy: 0.6608 - val_loss: 0.2030
# Epoch 13/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6079 - loss: 0.1580 - val_accuracy: 0.6957 - val_loss: 0.2245
# Epoch 14/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.5969 - loss: 0.1602 - val_accuracy: 0.7027 - val_loss: 0.2110
# Epoch 15/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6015 - loss: 0.1590 - val_accuracy: 0.7069 - val_loss: 0.2252
# Epoch 16/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6068 - loss: 0.1566 - val_accuracy: 0.6912 - val_loss: 0.2182
# Epoch 17/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6058 - loss: 0.1561 - val_accuracy: 0.7299 - val_loss: 0.1948
# Epoch 18/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6127 - loss: 0.1550 - val_accuracy: 0.7102 - val_loss: 0.1931
# Epoch 19/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6077 - loss: 0.1557 - val_accuracy: 0.6850 - val_loss: 0.2051
# Epoch 20/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6064 - loss: 0.1566 - val_accuracy: 0.6702 - val_loss: 0.2144
# Epoch 21/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6079 - loss: 0.1547 - val_accuracy: 0.7074 - val_loss: 0.2099
# Epoch 22/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6054 - loss: 0.1556 - val_accuracy: 0.6850 - val_loss: 0.2065
# Epoch 23/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6208 - loss: 0.1524 - val_accuracy: 0.6545 - val_loss: 0.2013
# Epoch 24/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6210 - loss: 0.1516 - val_accuracy: 0.6880 - val_loss: 0.2087
# Epoch 25/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6174 - loss: 0.1514 - val_accuracy: 0.7014 - val_loss: 0.1982
# Epoch 26/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6251 - loss: 0.1502 - val_accuracy: 0.6899 - val_loss: 0.1916
# Epoch 27/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6253 - loss: 0.1512 - val_accuracy: 0.7007 - val_loss: 0.2040
# Epoch 28/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6208 - loss: 0.1510 - val_accuracy: 0.7251 - val_loss: 0.1938
# Epoch 29/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6254 - loss: 0.1494 - val_accuracy: 0.6670 - val_loss: 0.2080
# Epoch 30/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6268 - loss: 0.1497 - val_accuracy: 0.6992 - val_loss: 0.1976
# Epoch 31/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6311 - loss: 0.1479 - val_accuracy: 0.6899 - val_loss: 0.2032
# Epoch 32/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6234 - loss: 0.1506 - val_accuracy: 0.6984 - val_loss: 0.2085
# Epoch 33/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6220 - loss: 0.1505 - val_accuracy: 0.6311 - val_loss: 0.2467
# Epoch 34/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6264 - loss: 0.1494 - val_accuracy: 0.7146 - val_loss: 0.1973
# Epoch 35/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6239 - loss: 0.1505 - val_accuracy: 0.7159 - val_loss: 0.1931
# Epoch 36/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6306 - loss: 0.1498 - val_accuracy: 0.6837 - val_loss: 0.2035
# Epoch 37/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6252 - loss: 0.1510 - val_accuracy: 0.7164 - val_loss: 0.2060
# Epoch 38/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6145 - loss: 0.1539 - val_accuracy: 0.7181 - val_loss: 0.2013
# Epoch 39/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6046 - loss: 0.1573 - val_accuracy: 0.7084 - val_loss: 0.2085
# Epoch 40/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6173 - loss: 0.1531 - val_accuracy: 0.6760 - val_loss: 0.2054
# Epoch 41/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6282 - loss: 0.1499 - val_accuracy: 0.6518 - val_loss: 0.1939
# Epoch 42/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6300 - loss: 0.1474 - val_accuracy: 0.7176 - val_loss: 0.1870
# Epoch 43/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6357 - loss: 0.1467 - val_accuracy: 0.7087 - val_loss: 0.2002
# Epoch 44/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6272 - loss: 0.1491 - val_accuracy: 0.7042 - val_loss: 0.1986
# Epoch 45/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6245 - loss: 0.1495 - val_accuracy: 0.7089 - val_loss: 0.2011
# Epoch 46/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6285 - loss: 0.1487 - val_accuracy: 0.7057 - val_loss: 0.2148
# Epoch 47/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6285 - loss: 0.1491 - val_accuracy: 0.7034 - val_loss: 0.1909
# Epoch 48/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6246 - loss: 0.1507 - val_accuracy: 0.6842 - val_loss: 0.2147
# Epoch 49/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6232 - loss: 0.1512 - val_accuracy: 0.7156 - val_loss: 0.1948
# Epoch 50/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6293 - loss: 0.1502 - val_accuracy: 0.7079 - val_loss: 0.2159
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
#
# === Precision, Recall, F1-Score per Label ===
#    Label  Precision    Recall  F1-Score
# 0      0   0.670103  0.693333  0.681520
# 1      1   0.225806  0.518519  0.314607
# 2      2   0.461538  0.582524  0.515021
# 3      3   0.528986  0.695238  0.600823
# 4      4   0.904651  0.775673  0.835212
#
# === Macro Averages & Accuracy ===
# Macro Precision: 0.5582
# Macro Recall: 0.6531
# Macro F1-Score: 0.5894
# Accuracy: 0.7311
#
# === Weighted Averages ===
# Weighted Precision: 0.7768
# Weighted Recall: 0.7311
# Weighted F1-Score: 0.7478
#
# === AUC-ROC ===
# AUC Macro: 0.8614
# AUC Weighted: 0.8522
# AUC per Label: [0.85583136 0.88467377 0.86950054 0.84923841 0.84757658]
#
# === Confusion Matrix ===
#      0   1   2   3    4
# 0  260  27  30   2   56
# 1   17  28   1   2    6
# 2   28   3  60   5    7
# 3    4  10   5  73   13
# 4   79  56  34  56  778
#
# Train Time: 454.29 seconds
# Test Time: 0.69 seconds

# %%
process_week(2, best_params, results)
# Out:
# === Processing Week 2 ===
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.4639 - loss: 0.1981 - val_accuracy: 0.6401 - val_loss: 0.2454
# Epoch 2/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.5593 - loss: 0.1637 - val_accuracy: 0.7179 - val_loss: 0.2199
# Epoch 3/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.5988 - loss: 0.1557 - val_accuracy: 0.7169 - val_loss: 0.1794
# Epoch 4/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6246 - loss: 0.1448 - val_accuracy: 0.5962 - val_loss: 0.2083
# Epoch 5/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6593 - loss: 0.1293 - val_accuracy: 0.6675 - val_loss: 0.1701
# Epoch 6/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6909 - loss: 0.1166 - val_accuracy: 0.6782 - val_loss: 0.2015
# Epoch 7/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7136 - loss: 0.1042 - val_accuracy: 0.6875 - val_loss: 0.1400
# Epoch 8/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7385 - loss: 0.0930 - val_accuracy: 0.7097 - val_loss: 0.1460
# Epoch 9/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7560 - loss: 0.0849 - val_accuracy: 0.6351 - val_loss: 0.1322
# Epoch 10/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7627 - loss: 0.0808 - val_accuracy: 0.6904 - val_loss: 0.1534
# Epoch 11/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7641 - loss: 0.0798 - val_accuracy: 0.6904 - val_loss: 0.1139
# Epoch 12/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7854 - loss: 0.0739 - val_accuracy: 0.6912 - val_loss: 0.1052
# Epoch 13/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7857 - loss: 0.0725 - val_accuracy: 0.7129 - val_loss: 0.0805
# Epoch 14/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8035 - loss: 0.0672 - val_accuracy: 0.6338 - val_loss: 0.1116
# Epoch 15/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8072 - loss: 0.0633 - val_accuracy: 0.6877 - val_loss: 0.1112
# Epoch 16/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8135 - loss: 0.0628 - val_accuracy: 0.6927 - val_loss: 0.0904
# Epoch 17/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8138 - loss: 0.0620 - val_accuracy: 0.6705 - val_loss: 0.1230
# Epoch 18/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8133 - loss: 0.0623 - val_accuracy: 0.6715 - val_loss: 0.1151
# Epoch 19/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.8184 - loss: 0.0600 - val_accuracy: 0.7221 - val_loss: 0.0873
# Epoch 20/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8216 - loss: 0.0612 - val_accuracy: 0.6653 - val_loss: 0.1199
# Epoch 21/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8360 - loss: 0.0564 - val_accuracy: 0.6288 - val_loss: 0.1113
# Epoch 22/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8386 - loss: 0.0535 - val_accuracy: 0.7214 - val_loss: 0.0870
# Epoch 23/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8379 - loss: 0.0545 - val_accuracy: 0.6964 - val_loss: 0.0857
# Epoch 24/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8373 - loss: 0.0540 - val_accuracy: 0.7383 - val_loss: 0.0786
# Epoch 25/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8362 - loss: 0.0560 - val_accuracy: 0.6505 - val_loss: 0.1463
# Epoch 26/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8389 - loss: 0.0557 - val_accuracy: 0.7378 - val_loss: 0.0693
# Epoch 27/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8464 - loss: 0.0525 - val_accuracy: 0.7446 - val_loss: 0.0759
# Epoch 28/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8416 - loss: 0.0546 - val_accuracy: 0.6964 - val_loss: 0.0852
# Epoch 29/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8471 - loss: 0.0524 - val_accuracy: 0.7356 - val_loss: 0.0751
# Epoch 30/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8484 - loss: 0.0517 - val_accuracy: 0.7423 - val_loss: 0.0876
# Epoch 31/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8524 - loss: 0.0505 - val_accuracy: 0.7191 - val_loss: 0.0743
# Epoch 32/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8561 - loss: 0.0485 - val_accuracy: 0.7151 - val_loss: 0.0782
# Epoch 33/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8569 - loss: 0.0481 - val_accuracy: 0.6675 - val_loss: 0.1171
# Epoch 34/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8601 - loss: 0.0483 - val_accuracy: 0.6870 - val_loss: 0.0882
# Epoch 35/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8589 - loss: 0.0476 - val_accuracy: 0.6752 - val_loss: 0.0860
# Epoch 36/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8639 - loss: 0.0456 - val_accuracy: 0.7558 - val_loss: 0.0686
# Epoch 37/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8625 - loss: 0.0475 - val_accuracy: 0.6934 - val_loss: 0.0885
# Epoch 38/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8628 - loss: 0.0464 - val_accuracy: 0.7443 - val_loss: 0.0720
# Epoch 39/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8589 - loss: 0.0484 - val_accuracy: 0.7249 - val_loss: 0.0857
# Epoch 40/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8664 - loss: 0.0458 - val_accuracy: 0.7176 - val_loss: 0.0848
# Epoch 41/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8602 - loss: 0.0465 - val_accuracy: 0.7496 - val_loss: 0.1027
# Epoch 42/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8680 - loss: 0.0432 - val_accuracy: 0.7294 - val_loss: 0.0886
# Epoch 43/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8663 - loss: 0.0454 - val_accuracy: 0.6924 - val_loss: 0.0886
# Epoch 44/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8757 - loss: 0.0432 - val_accuracy: 0.6964 - val_loss: 0.0716
# Epoch 45/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8640 - loss: 0.0464 - val_accuracy: 0.7433 - val_loss: 0.0635
# Epoch 46/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8781 - loss: 0.0415 - val_accuracy: 0.6785 - val_loss: 0.0722
# Epoch 47/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8713 - loss: 0.0440 - val_accuracy: 0.7670 - val_loss: 0.0614
# Epoch 48/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8745 - loss: 0.0434 - val_accuracy: 0.7760 - val_loss: 0.0622
# Epoch 49/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8668 - loss: 0.0435 - val_accuracy: 0.7461 - val_loss: 0.0754
# Epoch 50/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8732 - loss: 0.0435 - val_accuracy: 0.7062 - val_loss: 0.0918
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
#
# === Precision, Recall, F1-Score per Label ===
#    Label  Precision    Recall  F1-Score
# 0      0   0.788079  0.952000  0.862319
# 1      1   0.866667  0.962963  0.912281
# 2      2   0.714286  0.873786  0.786026
# 3      3   0.843373  0.666667  0.744681
# 4      4   0.982571  0.899302  0.939094
#
# === Macro Averages & Accuracy ===
# Macro Precision: 0.8390
# Macro Recall: 0.8709
# Macro F1-Score: 0.8489
# Accuracy: 0.8970
#
# === Weighted Averages ===
# Weighted Precision: 0.9085
# Weighted Recall: 0.8970
# Weighted F1-Score: 0.8986
#
# === AUC-ROC ===
# AUC Macro: 0.9868
# AUC Weighted: 0.9871
# AUC per Label: [0.98267194 0.99933445 0.98327975 0.97968668 0.98920663]
#
# === Confusion Matrix ===
#      0   1   2   3    4
# 0  357   5   6   1    6
# 1    1  52   1   0    0
# 2    7   1  90   2    3
# 3    6   0  22  70    7
# 4   82   2   7  10  902
#
# Train Time: 450.37 seconds
# Test Time: 0.69 seconds

# %%
process_week(3, best_params, results)
# Out:
# === Processing Week 3 ===
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.4513 - loss: 0.1995 - val_accuracy: 0.6386 - val_loss: 0.2651
# Epoch 2/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.5097 - loss: 0.1807 - val_accuracy: 0.6488 - val_loss: 0.2382
# Epoch 3/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.5260 - loss: 0.1754 - val_accuracy: 0.5957 - val_loss: 0.2603
# Epoch 4/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.5339 - loss: 0.1728 - val_accuracy: 0.6219 - val_loss: 0.2172
# Epoch 5/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.5394 - loss: 0.1690 - val_accuracy: 0.7151 - val_loss: 0.2020
# Epoch 6/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.5683 - loss: 0.1579 - val_accuracy: 0.7189 - val_loss: 0.2058
# Epoch 7/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.5725 - loss: 0.1581 - val_accuracy: 0.6692 - val_loss: 0.2189
# Epoch 8/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.5958 - loss: 0.1478 - val_accuracy: 0.6825 - val_loss: 0.2143
# Epoch 9/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.6008 - loss: 0.1446 - val_accuracy: 0.5276 - val_loss: 0.1934
# Epoch 10/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.6221 - loss: 0.1369 - val_accuracy: 0.6495 - val_loss: 0.1745
# Epoch 11/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6430 - loss: 0.1314 - val_accuracy: 0.6493 - val_loss: 0.1776
# Epoch 12/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6509 - loss: 0.1290 - val_accuracy: 0.6665 - val_loss: 0.1636
# Epoch 13/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.6728 - loss: 0.1204 - val_accuracy: 0.6962 - val_loss: 0.1730
# Epoch 14/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.6884 - loss: 0.1137 - val_accuracy: 0.7067 - val_loss: 0.1667
# Epoch 15/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6968 - loss: 0.1120 - val_accuracy: 0.7027 - val_loss: 0.1335
# Epoch 16/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7024 - loss: 0.1079 - val_accuracy: 0.7398 - val_loss: 0.1211
# Epoch 17/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.7237 - loss: 0.0990 - val_accuracy: 0.6034 - val_loss: 0.1250
# Epoch 18/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7109 - loss: 0.1050 - val_accuracy: 0.5690 - val_loss: 0.1230
# Epoch 19/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7410 - loss: 0.0914 - val_accuracy: 0.7650 - val_loss: 0.1039
# Epoch 20/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7485 - loss: 0.0889 - val_accuracy: 0.5388 - val_loss: 0.1142
# Epoch 21/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.7562 - loss: 0.0866 - val_accuracy: 0.7079 - val_loss: 0.1173
# Epoch 22/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7587 - loss: 0.0858 - val_accuracy: 0.6475 - val_loss: 0.1012
# Epoch 23/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.7704 - loss: 0.0802 - val_accuracy: 0.7446 - val_loss: 0.0886
# Epoch 24/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7624 - loss: 0.0843 - val_accuracy: 0.6807 - val_loss: 0.1269
# Epoch 25/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.7848 - loss: 0.0761 - val_accuracy: 0.7151 - val_loss: 0.1182
# Epoch 26/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7720 - loss: 0.0791 - val_accuracy: 0.6967 - val_loss: 0.0870
# Epoch 27/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.7719 - loss: 0.0793 - val_accuracy: 0.7057 - val_loss: 0.0932
# Epoch 28/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7881 - loss: 0.0738 - val_accuracy: 0.7047 - val_loss: 0.0780
# Epoch 29/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7881 - loss: 0.0743 - val_accuracy: 0.7585 - val_loss: 0.0850
# Epoch 30/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8002 - loss: 0.0711 - val_accuracy: 0.7019 - val_loss: 0.1094
# Epoch 31/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.7958 - loss: 0.0707 - val_accuracy: 0.7398 - val_loss: 0.0701
# Epoch 32/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8009 - loss: 0.0695 - val_accuracy: 0.7418 - val_loss: 0.1004
# Epoch 33/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8070 - loss: 0.0678 - val_accuracy: 0.6737 - val_loss: 0.1093
# Epoch 34/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7968 - loss: 0.0711 - val_accuracy: 0.6982 - val_loss: 0.0940
# Epoch 35/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8063 - loss: 0.0685 - val_accuracy: 0.6835 - val_loss: 0.0952
# Epoch 36/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7955 - loss: 0.0711 - val_accuracy: 0.7037 - val_loss: 0.0836
# Epoch 37/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8194 - loss: 0.0642 - val_accuracy: 0.7214 - val_loss: 0.0852
# Epoch 38/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8208 - loss: 0.0628 - val_accuracy: 0.6483 - val_loss: 0.0834
# Epoch 39/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8108 - loss: 0.0668 - val_accuracy: 0.7107 - val_loss: 0.0820
# Epoch 40/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8230 - loss: 0.0614 - val_accuracy: 0.6645 - val_loss: 0.0764
# Epoch 41/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8088 - loss: 0.0658 - val_accuracy: 0.7466 - val_loss: 0.0853
# Epoch 42/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8290 - loss: 0.0595 - val_accuracy: 0.5515 - val_loss: 0.0883
# Epoch 43/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8259 - loss: 0.0618 - val_accuracy: 0.7348 - val_loss: 0.0849
# Epoch 44/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8264 - loss: 0.0621 - val_accuracy: 0.7107 - val_loss: 0.0932
# Epoch 45/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8284 - loss: 0.0600 - val_accuracy: 0.7990 - val_loss: 0.0648
# Epoch 46/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8235 - loss: 0.0608 - val_accuracy: 0.6979 - val_loss: 0.0927
# Epoch 47/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8233 - loss: 0.0632 - val_accuracy: 0.6820 - val_loss: 0.0800
# Epoch 48/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8250 - loss: 0.0611 - val_accuracy: 0.7186 - val_loss: 0.0803
# Epoch 49/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8233 - loss: 0.0620 - val_accuracy: 0.7009 - val_loss: 0.0766
# Epoch 50/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8269 - loss: 0.0606 - val_accuracy: 0.6460 - val_loss: 0.1120
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
#
# === Precision, Recall, F1-Score per Label ===
#    Label  Precision    Recall  F1-Score
# 0      0   0.908587  0.874667  0.891304
# 1      1   0.796610  0.870370  0.831858
# 2      2   0.652174  0.873786  0.746888
# 3      3   0.957746  0.647619  0.772727
# 4      4   0.950544  0.958126  0.954320
#
# === Macro Averages & Accuracy ===
# Macro Precision: 0.8531
# Macro Recall: 0.8449
# Macro F1-Score: 0.8394
# Accuracy: 0.9110
#
# === Weighted Averages ===
# Weighted Precision: 0.9176
# Weighted Recall: 0.9110
# Weighted F1-Score: 0.9112
#
# === AUC-ROC ===
# AUC Macro: 0.9786
# AUC Weighted: 0.9808
# AUC per Label: [0.97378867 0.98301107 0.96960413 0.98208159 0.98430141]
#
# === Confusion Matrix ===
#      0   1   2   3    4
# 0  328   1   8   1   37
# 1    2  47   2   1    2
# 2    6   0  90   0    7
# 3    1   2  30  68    4
# 4   24   9   8   1  961
#
# Train Time: 436.76 seconds
# Test Time: 0.70 seconds

# %%
process_week(4, best_params, results)
# Out:
# === Processing Week 4 ===
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.4055 - loss: 0.2127 - val_accuracy: 0.5879 - val_loss: 0.2900
# Epoch 2/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.4765 - loss: 0.1911 - val_accuracy: 0.6433 - val_loss: 0.2283
# Epoch 3/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.5333 - loss: 0.1723 - val_accuracy: 0.5914 - val_loss: 0.2622
# Epoch 4/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.5552 - loss: 0.1627 - val_accuracy: 0.5922 - val_loss: 0.2478
# Epoch 5/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.5709 - loss: 0.1583 - val_accuracy: 0.6054 - val_loss: 0.2610
# Epoch 6/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.5881 - loss: 0.1551 - val_accuracy: 0.6767 - val_loss: 0.2146
# Epoch 7/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6177 - loss: 0.1425 - val_accuracy: 0.6667 - val_loss: 0.2064
# Epoch 8/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6250 - loss: 0.1400 - val_accuracy: 0.7027 - val_loss: 0.1952
# Epoch 9/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6480 - loss: 0.1317 - val_accuracy: 0.1818 - val_loss: 0.3861
# Epoch 10/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6082 - loss: 0.1438 - val_accuracy: 0.2604 - val_loss: 0.2486
# Epoch 11/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6510 - loss: 0.1271 - val_accuracy: 0.6291 - val_loss: 0.1794
# Epoch 12/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6502 - loss: 0.1292 - val_accuracy: 0.4999 - val_loss: 0.1589
# Epoch 13/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6605 - loss: 0.1262 - val_accuracy: 0.5765 - val_loss: 0.1792
# Epoch 14/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6785 - loss: 0.1200 - val_accuracy: 0.7518 - val_loss: 0.0882
# Epoch 15/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6927 - loss: 0.1154 - val_accuracy: 0.5819 - val_loss: 0.2203
# Epoch 16/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6793 - loss: 0.1182 - val_accuracy: 0.6253 - val_loss: 0.1480
# Epoch 17/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6916 - loss: 0.1122 - val_accuracy: 0.6500 - val_loss: 0.1161
# Epoch 18/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7012 - loss: 0.1086 - val_accuracy: 0.6565 - val_loss: 0.1360
# Epoch 19/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6983 - loss: 0.1125 - val_accuracy: 0.6638 - val_loss: 0.0902
# Epoch 20/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7190 - loss: 0.1050 - val_accuracy: 0.5291 - val_loss: 0.1423
# Epoch 21/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6328 - loss: 0.1335 - val_accuracy: 0.4567 - val_loss: 0.2877
# Epoch 22/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.5399 - loss: 0.1648 - val_accuracy: 0.6231 - val_loss: 0.0881
# Epoch 23/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7087 - loss: 0.1059 - val_accuracy: 0.5999 - val_loss: 0.1384
# Epoch 24/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7293 - loss: 0.0962 - val_accuracy: 0.6256 - val_loss: 0.1273
# Epoch 25/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7340 - loss: 0.0927 - val_accuracy: 0.7533 - val_loss: 0.0773
# Epoch 26/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7558 - loss: 0.0849 - val_accuracy: 0.4390 - val_loss: 0.2045
# Epoch 27/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7528 - loss: 0.0851 - val_accuracy: 0.6560 - val_loss: 0.1217
# Epoch 28/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7538 - loss: 0.0808 - val_accuracy: 0.6615 - val_loss: 0.0761
# Epoch 29/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7531 - loss: 0.0796 - val_accuracy: 0.4467 - val_loss: 0.1313
# Epoch 30/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7568 - loss: 0.0762 - val_accuracy: 0.7493 - val_loss: 0.0581
# Epoch 31/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7459 - loss: 0.0794 - val_accuracy: 0.5597 - val_loss: 0.0973
# Epoch 32/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7242 - loss: 0.0832 - val_accuracy: 0.4388 - val_loss: 0.1136
# Epoch 33/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7646 - loss: 0.0734 - val_accuracy: 0.4757 - val_loss: 0.1282
# Epoch 34/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7590 - loss: 0.0715 - val_accuracy: 0.4807 - val_loss: 0.0987
# Epoch 35/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7792 - loss: 0.0688 - val_accuracy: 0.4118 - val_loss: 0.1199
# Epoch 36/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7725 - loss: 0.0701 - val_accuracy: 0.5927 - val_loss: 0.0844
# Epoch 37/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7763 - loss: 0.0703 - val_accuracy: 0.2240 - val_loss: 0.1922
# Epoch 38/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7686 - loss: 0.0707 - val_accuracy: 0.4268 - val_loss: 0.1550
# Epoch 39/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7538 - loss: 0.0744 - val_accuracy: 0.3944 - val_loss: 0.1448
# Epoch 40/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6745 - loss: 0.0898 - val_accuracy: 0.4348 - val_loss: 0.1623
# Epoch 41/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7566 - loss: 0.0731 - val_accuracy: 0.5640 - val_loss: 0.0761
# Epoch 42/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7753 - loss: 0.0680 - val_accuracy: 0.6855 - val_loss: 0.0953
# Epoch 43/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7757 - loss: 0.0688 - val_accuracy: 0.1689 - val_loss: 0.2111
# Epoch 44/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7759 - loss: 0.0679 - val_accuracy: 0.3784 - val_loss: 0.1297
# Epoch 45/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7806 - loss: 0.0669 - val_accuracy: 0.2676 - val_loss: 0.1825
# Epoch 46/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7463 - loss: 0.0755 - val_accuracy: 0.7496 - val_loss: 0.0667
# Epoch 47/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7740 - loss: 0.0669 - val_accuracy: 0.3941 - val_loss: 0.1446
# Epoch 48/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7863 - loss: 0.0631 - val_accuracy: 0.4300 - val_loss: 0.1120
# Epoch 49/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7757 - loss: 0.0681 - val_accuracy: 0.4293 - val_loss: 0.1424
# Epoch 50/50
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7802 - loss: 0.0679 - val_accuracy: 0.4505 - val_loss: 0.1187
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
#
# === Precision, Recall, F1-Score per Label ===
#    Label  Precision    Recall  F1-Score
# 0      0   0.000000  0.000000  0.000000
# 1      1   0.764706  0.962963  0.852459
# 2      2   0.244499  0.970874  0.390625
# 3      3   0.224044  0.390476  0.284722
# 4      4   1.000000  0.976072  0.987891
#
# === Macro Averages & Accuracy ===
# Macro Precision: 0.4466
# Macro Recall: 0.6601
# Macro F1-Score: 0.5031
# Accuracy: 0.7146
#
# === Weighted Averages ===
# Weighted Precision: 0.6665
# Weighted Recall: 0.7146
# Weighted F1-Score: 0.6750
#
# === AUC-ROC ===
# AUC Macro: 0.9662
# AUC Weighted: 0.9868
# AUC per Label: [0.98396206 0.97195367 0.98216801 0.89421436 0.99874943]
#
# === Confusion Matrix ===
#    0   1    2    3    4
# 0  0   1  235  139    0
# 1  0  52    1    1    0
# 2  0   3  100    0    0
# 3  0   1   63   41    0
# 4  1  11   10    2  979
#
# Train Time: 450.39 seconds
# Test Time: 0.73 seconds

# %%
# Hiển thị dữ liệu của các tuần
print("\n=== Summary Results for All Weeks ===")
for result in results:
    print(f"Week {result['week']}:")
    print(f"  Train Time: {result['train_time']:.2f} seconds")
    print(f"  Test Time: {result['test_time']:.2f} seconds")
    print(f"  Accurancy: {result['accuracy']}")
    print(f"  Precision: {result['precision']}")
    print(f"  Recall: {result['recall']}")
    print(f"  F1-Score: {result['f1_score']}")
    print(f"  Macro Precision: {result['precision_macro']}")
    print(f"  Macro Recall: {result['recall_macro']}")
    print(f"  Macro F1-Score: {result['f1_macro']}")
    print(f"  Confusion Matrix:\n{result['confusion_matrix']}")
    print("\n=== AUC-ROC ===")
    print(f"AUC Macro: {auc_macro:.4f}")
    print(f"AUC Weighted: {auc_weighted:.4f}")
    print(f"AUC per Label: {auc_per_class}")
# Out:
# === Summary Results for All Weeks ===
# Week 1:
#   Train Time: 454.29 seconds
#   Test Time: 0.69 seconds
#   Accurancy: 0.7310975609756097
#   Precision: [0.67010309 0.22580645 0.46153846 0.52898551 0.90465116]
#   Recall: [0.69333333 0.51851852 0.58252427 0.6952381  0.77567298]
#   F1-Score: [0.68152031 0.31460674 0.51502146 0.60082305 0.83521202]
#   Macro Precision: 0.5582169351943889
#   Macro Recall: 0.6530574399982874
#   Macro F1-Score: 0.5894367168467299
#   Confusion Matrix:
# [[260  27  30   2  56]
#  [ 17  28   1   2   6]
#  [ 28   3  60   5   7]
#  [  4  10   5  73  13]
#  [ 79  56  34  56 778]]
#
# === AUC-ROC ===
# AUC Macro: 0.9359
# AUC Weighted: 0.9747
# AUC per Label: [0.95215917 0.87125323 0.93022039 0.92781687 0.99824299]
# Week 2:
#   Train Time: 450.37 seconds
#   Test Time: 0.69 seconds
#   Accurancy: 0.8969512195121951
#   Precision: [0.78807947 0.86666667 0.71428571 0.84337349 0.98257081]
#   Recall: [0.952      0.96296296 0.87378641 0.66666667 0.89930209]
#   F1-Score: [0.86231884 0.9122807  0.7860262  0.74468085 0.93909422]
#   Macro Precision: 0.8389952302454355
#   Macro Recall: 0.8709436262230927
#   Macro F1-Score: 0.8488801632061577
#   Confusion Matrix:
# [[357   5   6   1   6]
#  [  1  52   1   0   0]
#  [  7   1  90   2   3]
#  [  6   0  22  70   7]
#  [ 82   2   7  10 902]]
#
# === AUC-ROC ===
# AUC Macro: 0.9359
# AUC Weighted: 0.9747
# AUC per Label: [0.95215917 0.87125323 0.93022039 0.92781687 0.99824299]
# Week 3:
#   Train Time: 436.76 seconds
#   Test Time: 0.70 seconds
#   Accurancy: 0.9109756097560976
#   Precision: [0.90858726 0.79661017 0.65217391 0.95774648 0.95054402]
#   Recall: [0.87466667 0.87037037 0.87378641 0.64761905 0.95812562]
#   F1-Score: [0.89130435 0.83185841 0.74688797 0.77272727 0.95431976]
#   Macro Precision: 0.8531323669703774
#   Macro Recall: 0.8449136231107366
#   Macro F1-Score: 0.8394195512212613
#   Confusion Matrix:
# [[328   1   8   1  37]
#  [  2  47   2   1   2]
#  [  6   0  90   0   7]
#  [  1   2  30  68   4]
#  [ 24   9   8   1 961]]
#
# === AUC-ROC ===
# AUC Macro: 0.9359
# AUC Weighted: 0.9747
# AUC per Label: [0.95215917 0.87125323 0.93022039 0.92781687 0.99824299]
# Week 4:
#   Train Time: 450.39 seconds
#   Test Time: 0.73 seconds
#   Accurancy: 0.7146341463414634
#   Precision: [0.         0.76470588 0.24449878 0.22404372 1.        ]
#   Recall: [0.         0.96296296 0.97087379 0.39047619 0.97607178]
#   F1-Score: [0.         0.85245902 0.390625   0.28472222 0.98789102]
#   Macro Precision: 0.4466496751412096
#   Macro Recall: 0.6600769448985965
#   Macro F1-Score: 0.5031394515576435
#   Confusion Matrix:
# [[  0   1 235 139   0]
#  [  0  52   1   1   0]
#  [  0   3 100   0   0]
#  [  0   1  63  41   0]
#  [  1  11  10   2 979]]
#
# === AUC-ROC ===
# AUC Macro: 0.9359
# AUC Weighted: 0.9747
# AUC per Label: [0.95215917 0.87125323 0.93022039 0.92781687 0.99824299]
